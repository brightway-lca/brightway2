# %% [markdown]
# # Creating ecoinvent 3 migrations
#
# This notebook describes how migrations were created for ecoinvent versions 3.1 and 3.2 to 3.3. Migrations were created using the ecoinvent change spreadsheets, and some manual matching. Manual matching occurred outside of this notebook.
#
# Start by setting up a new project:

# %%
from brightway2 import *
projects.set_current("ecoinvent updates")

# %%
bw2setup()
# Out:
# Creating default biosphere
# Writing activities to SQLite3 database:
# 0%                          100%
# [##########                    ] | ETA[sec]: 0.371
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applied 2 strategies in 0.01 seconds
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 0.426 sec
# Title: Writing activities to SQLite3 database:
#   Started: 12/06/2016 10:51:41
#   Finished: 12/06/2016 10:51:41
#   Total time elapsed: 0.426 sec
#   CPU %: 101.800000
#   Memory %: 0.409055
# Created database: biosphere3
# Creating default LCIA methods
#
# Applying strategy: normalize_units
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applied 4 strategies in 0.97 seconds
# Wrote 718 LCIA methods with 178008 characterization factors
# Creating core data migrations

# %%
ei = SingleOutputEcospold2Importer(
    "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.1/cutoff/datasets", 
    "3.1 cutoff"
)
ei.apply_strategies()
ei.statistics()
# Out:
# Extracting XML data from 11301 datasets
# Extracted 11301 datasets in 39.37 seconds
# Applying strategy: normalize_units
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: nuncertainty
# Applied 13 strategies in 3.12 seconds
# 11301 datasets
# 521712 exchanges
# 780 unlinked exchanges
#   Type biosphere: 12 unique unlinked exchanges
# (11301, 521712, 780)

# %%
for x in ei.unlinked:
    print(x['name'])
# Out:
# Fluorene_temp
# Fluoranthene_temp
# Dibenz(a,h)anthracene_temp
# Benzo(k)fluoranthene_temp
# Benzo(ghi)perylene_temp
# Benzo(b)fluoranthene_temp
# Benzo(a)anthracene_temp
# Acenaphthylene_temp
# Chrysene_temp
# Pyrene_temp
# Phenanthrene_temp
# Indeno(1,2,3-c,d)pyrene_temp

# %% [markdown]
# These temporary flows can be safely dropped.

# %%
ei.drop_unlinked(True)
# Out:
# Applying strategy: drop_unlinked
# Applied 1 strategies in 0.16 seconds

# %%
ei.write_database()
# Out:
# Writing activities to SQLite3 database:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 48.384 sec
# Title: Writing activities to SQLite3 database:
#   Started: 12/06/2016 10:53:25
#   Finished: 12/06/2016 10:54:13
#   Total time elapsed: 48.384 sec
#   CPU %: 80.900000
#   Memory %: 3.420854
# Created database: 3.1 cutoff
# Brightway2 SQLiteBackend: 3.1 cutoff

# %%
ei = SingleOutputEcospold2Importer(
    "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.2/cutoff/datasets", 
    "3.2 cutoff"
)
ei.apply_strategies()
ei.statistics()
# Out:
# Extracting XML data from 12916 datasets
# Extracted 12916 datasets in 70.87 seconds
# Applying strategy: normalize_units
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: nuncertainty
# Applied 13 strategies in 2.76 seconds
# 12916 datasets
# 459268 exchanges
# 0 unlinked exchanges
# (12916, 459268, 0)

# %%
ei.write_database()
# Out:
# Writing activities to SQLite3 database:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 38.414 sec
# Title: Writing activities to SQLite3 database:
#   Started: 12/06/2016 10:56:15
#   Finished: 12/06/2016 10:56:54
#   Total time elapsed: 38.414 sec
#   CPU %: 88.000000
#   Memory %: 5.748880
# Created database: 3.2 cutoff
# Brightway2 SQLiteBackend: 3.2 cutoff

# %%
ei = SingleOutputEcospold2Importer(
    "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.3/cutoff/datasets", 
    "3.3 cutoff"
)
ei.apply_strategies()
ei.statistics()
# Out:
# Extracting XML data from 13831 datasets
# Extracted 13831 datasets in 121.34 seconds
# Applying strategy: normalize_units
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: nuncertainty
# Applied 13 strategies in 3.17 seconds
# 13831 datasets
# 501148 exchanges
# 0 unlinked exchanges
# (13831, 501148, 0)

# %%
ei.write_database()
# Out:
# Writing activities to SQLite3 database:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 44.089 sec
# Title: Writing activities to SQLite3 database:
#   Started: 12/06/2016 10:59:53
#   Finished: 12/06/2016 11:00:37
#   Total time elapsed: 44.089 sec
#   CPU %: 85.600000
#   Memory %: 5.835319
# Created database: 3.3 cutoff
# Brightway2 SQLiteBackend: 3.3 cutoff

# %% [markdown]
# ## 3.1 to 3.3
#
# Which processes don't map exactly?

# %%
data_31 = {(ds['name'], ds['reference product'], ds['location']) for ds in Database("3.1 cutoff")}
data_33 = {(ds['name'], ds['reference product'], ds['location']) for ds in Database("3.3 cutoff")}

# %% [markdown]
# 814 out of 11301 activities are not the same in 3.3.

# %%
len(data_31), len(data_31.difference(data_33))
# Out:
# (11301, 814)

# %% [markdown]
# Let's get a selection of the missing activities.

# %%
list(data_31.difference(data_33))[:100]
# Out:
# [('market for scrap steel', 'scrap steel', 'GLO'),
#  ('electricity production, hard coal', 'electricity, high voltage', 'PL'),
#  ('electricity production, photovoltaic, 3kWp flat-roof installation, multi-Si',
#   'electricity, low voltage',
#   'TW'),
#  ('apple production', 'apple', 'GLO'),
#  ('treatment of manure and biowaste by anaerobic digestion, from manure, liquid, cattle',
#   'biogas',
#   'RoW'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'RoW'),
#  ('field application of potassium nitrate',
#   'potassium fertiliser, as K2O',
#   'GLO'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'NO'),
#  ('market for sawnwood, lath, hardwood, raw, air dried',
#   'sawnwood, lath, hardwood, raw, air dried',
#   'GLO'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CZ'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 3'),
#  ('market for electricity, high voltage', 'electricity, high voltage', 'CN'),
#  ('market for hazardous waste, for incineration',
#   'hazardous waste, for incineration',
#   'GLO'),
#  ('concrete production, normal', 'concrete, normal', 'CH'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-NS'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area 1'),
#  ('treatment of wastewater, average, capacity 1.6E8l/year',
#   'wastewater, average',
#   'RoW'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, ribbon-Si, panel, mounted',
#   'electricity, low voltage',
#   'MY'),
#  ('electricity production, photovoltaic, 3kWp facade installation, single-Si, laminated, integrated',
#   'electricity, low voltage',
#   'KR'),
#  ('market for lightweight concrete block, expanded clay',
#   'lightweight concrete block, expanded clay',
#   'GLO'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'CA-NT'),
#  ('field application of compost', 'phosphate fertiliser, as P2O5', 'GLO'),
#  ('market for pulpwood, hardwood, measured as solid wood under bark',
#   'pulpwood, hardwood, measured as solid wood under bark',
#   'GLO'),
#  ('market for sawnwood, board, hardwood, air dried, planed',
#   'sawnwood, board, hardwood, air dried, planed',
#   'GLO'),
#  ('sawing, softwood', 'saw dust, wet, measured as dry mass', 'CH'),
#  ('board, hardwood, raw, air drying',
#   'sawnwood, board, hardwood, raw, air dried',
#   'CH'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CdTe, laminated, integrated',
#   'electricity, low voltage',
#   'ZA'),
#  ('cement production, alternative constituents 6-20%', 'hard coal ash', 'CH'),
#  ('treatment of blast furnace slag, to inert waste',
#   'blast furnace slag',
#   'US'),
#  ('ethanol production from sugar cane',
#   'ethanol, without water, in 95% solution state, from fermentation',
#   'BR'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'KR'),
#  ('market for vine tomato', 'vine tomato', 'GLO'),
#  ('electricity, high voltage, import from TW',
#   'electricity, high voltage',
#   'CN'),
#  ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 1'),
#  ('diesel, burned in diesel-electric generating set',
#   'diesel, burned in diesel-electric generating set',
#   'GLO'),
#  ('rock wool production', 'rock wool', 'CH'),
#  ('harvest, roundwood, shrubland', 'roundwood', 'GLO'),
#  ('electricity production, nuclear, pressure water reactor',
#   'electricity, high voltage',
#   'IN'),
#  ('field application of potassium nitrate',
#   'nitrogen fertiliser, as N',
#   'GLO'),
#  ('cork forestry', 'cork, raw', 'RER'),
#  ('market for electricity, for reuse in municipal waste incineration only',
#   'electricity, for reuse in municipal waste incineration only',
#   'CA-NB'),
#  ('market for wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact, as(...)_5',
#   'wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact',
#   'GLO'),
#  ('treatment of manure and biowaste by anaerobic digestion', 'biogas', 'RoW'),
#  ('clear-cutting, shrubland to arable land',
#   'land tenure, arable land, measured as carbon net primary productivity',
#   'RAF'),
#  ('debarking, softwood',
#   'sawlog and veneer log, softwood, debarked, measured as solid wood',
#   'RoW'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-NB'),
#  ('planing, beam, hardwood, air dried',
#   'shaving, hardwood, measured as dry mass',
#   'RoW'),
#  ('market for inert waste', 'inert waste', 'GLO'),
#  ('board, hardwood, raw, kiln drying',
#   'sawnwood, board, hardwood, raw, kiln dried',
#   'RoW'),
#  ('market for electricity, for reuse in municipal waste incineration only',
#   'electricity, for reuse in municipal waste incineration only',
#   'CA-AB'),
#  ('market for wood preservation, spray tunnel/deluging, organic solvent-based, outdoor use, no ground contact, as am(...)_7',
#   'wood preservation, spray tunnel/deluging, organic solvent-based, outdoor use, no ground contact',
#   'GLO'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'PT'),
#  ('market for used silencer steel, DN 315',
#   'used silencer steel, DN 315',
#   'GLO'),
#  ('sawnwood production, hardwood, raw, air dried',
#   'sawnwood, hardwood, raw, air dried',
#   'RoW'),
#  ('market for green manure, organic, until April',
#   'green manure, organic, until April',
#   'GLO'),
#  ('market for used blower and heat exchange unit decentralized, 180-250 m3/h',
#   'used blower and heat exchange unit decentralized, 180-250 m3/h',
#   'GLO'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CIS, panel, mounted',
#   'electricity, low voltage',
#   'MY'),
#  ('electricity, high voltage, import from HR',
#   'electricity, high voltage',
#   'HU'),
#  ('aluminium production, primary, liquid, Söderberg',
#   'aluminium, primary, liquid',
#   'IAI Area 3'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'RFC'),
#  ('treatment of straw, organic, in furnace 300kW',
#   'heat, district or industrial, other than natural gas',
#   'GLO'),
#  ('planing, board, softwood, kiln dried',
#   'sawnwood, board, softwood, kiln dried, planed',
#   'CH'),
#  ('market for waste concrete', 'waste concrete', 'GLO'),
#  ('electricity production, hard coal', 'electricity, high voltage', 'BA'),
#  ('intensification, arable land',
#   'land tenure, arable land, measured as carbon net primary productivity',
#   'GLO'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CdTe, laminated, integrated',
#   'electricity, low voltage',
#   'MY'),
#  ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'UN-EUROPE'),
#  ('market for tomato', 'tomato', 'GLO'),
#  ('market for used sealing tape aluminium/PE, 50 mm wide',
#   'used sealing tape aluminium/PE, 50 mm wide',
#   'GLO'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 4&5 without China'),
#  ('market for used insulation spiral-seam duct rockwool, DN 400',
#   'used insulation spiral-seam duct rockwool, DN 400',
#   'GLO'),
#  ('market for barley seed, Swiss integrated production, for sowing',
#   'barley seed, Swiss integrated production, for sowing',
#   'GLO'),
#  ('electricity production, geothermal', 'electricity, high voltage', 'JP'),
#  ('market for fly ash and scrubber sludge',
#   'fly ash and scrubber sludge',
#   'GLO'),
#  ('planing, board, softwood, kiln dried',
#   'shaving, softwood, measured as dry mass',
#   'RoW'),
#  ('concrete production, sole plate and foundation',
#   'concrete, sole plate and foundation',
#   'CH'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'CA-MB'),
#  ('market for sawnwood, hardwood, raw, air dried',
#   'sawnwood, hardwood, raw, air dried',
#   'RoW'),
#  ('pear production', 'pear', 'GLO'),
#  ('electricity production, lignite', 'electricity, high voltage', 'PL'),
#  ('market for rape seed, for sowing', 'rape seed, for sowing', 'GLO'),
#  ('market for anhydrite rock', 'anhydrite rock', 'GLO'),
#  ('rock wool factory construction', 'rock wool factory', 'RoW'),
#  ('market for concrete, high exacting requirements',
#   'concrete, high exacting requirements',
#   'GLO'),
#  ('electricity production, photovoltaic, 3kWp facade installation, single-Si, panel, mounted',
#   'electricity, low voltage',
#   'TW'),
#  ('treatment of manure and biowaste by anaerobic digestion', 'biogas', 'CH'),
#  ('treatment of coal gas, in power plant',
#   'heat, district or industrial, other than natural gas',
#   'CN'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 8'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'UA'),
#  ('market for brick shale', 'brick shale', 'GLO'),
#  ('treatment of biogas, purification to methane 96 vol-%',
#   'methane, 96% by volume',
#   'RoW'),
#  ('tree seedling production, in unheated greenhouse', 'tree seedling', 'RoW'),
#  ('lath, softwood, raw, air drying',
#   'sawnwood, lath, softwood, raw, air dried',
#   'CH'),
#  ('tree seedling production, in heated greenhouse', 'tree seedling', 'RER'),
#  ('electricity production, lignite', 'electricity, high voltage', 'UA'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, a-Si, panel, mounted',
#   'electricity, low voltage',
#   'TW'),
#  ('market for diesel, burned in diesel-electric generating set',
#   'diesel, burned in diesel-electric generating set',
#   'GLO'),
#  ('market for sawnwood, lath, softwood, raw, kiln dried',
#   'sawnwood, lath, softwood, raw, kiln dried',
#   'GLO'),
#  ('planing, beam, hardwood, air dried',
#   'sawnwood, beam, hardwood, air dried, planed',
#   'CH'),
#  ('planing, board, hardwood, air dried',
#   'shaving, hardwood, measured as dry mass',
#   'RoW')]

# %% [markdown]
# ## Official ecoinvent update list
#
# Let's look at the official ecoinvent update Excel sheet. These are provided by ecoinvent in the "files" section (you have to be logged in; I have changed the filenames as well).
#
# From these files, we need to get two things:
#
# 1. A list of activities which have had their names or reference products changed
# 2. A list of activities which have had major changes and need to be matched manually

# %%
import os
import pandas as pd
import math

# %% [markdown]
# ### `Deleted or replaced` activities

# %%
overview = pd.read_excel("ecoinvent 3.1-3.2.xlsx", "overview")

# %%
overview['status'].unique()
# Out:
# array(['in both versions', 'new', 'deleted or replaced'], dtype=object)

# %%
overview
# Out:
#       ISIC number                                         ISIC class  \
# 0            2011                     Manufacture of basic chemicals
# 1            2011                     Manufacture of basic chemicals
# 2              20     Manufacture of chemicals and chemical products
# 3            2011                     Manufacture of basic chemicals
# 4            2011                     Manufacture of basic chemicals
# 5              20     Manufacture of chemicals and chemical products
# 6            2011                     Manufacture of basic chemicals
# 7            2011                     Manufacture of basic chemicals
# 8            2011                     Manufacture of basic chemicals
# 9            2011                     Manufacture of basic chemicals
# 10           2011                     Manufacture of basic chemicals
# 11           2011                     Manufacture of basic chemicals
# 12           2011                     Manufacture of basic chemicals
# 13           2011                     Manufacture of basic chemicals
# 14             20     Manufacture of chemicals and chemical products
# 15           2011                     Manufacture of basic chemicals
# 16           2011                     Manufacture of basic chemicals
# 17           2011                     Manufacture of basic chemicals
# 18           2011                     Manufacture of basic chemicals
# 19           2011                     Manufacture of basic chemicals
# 20           2011                     Manufacture of basic chemicals
# 21           2011                     Manufacture of basic chemicals
# 22           2011                     Manufacture of basic chemicals
# 23           2011                     Manufacture of basic chemicals
# 24           2011                     Manufacture of basic chemicals
# 25           2011                     Manufacture of basic chemicals
# 26           2011                     Manufacture of basic chemicals
# 27           2011                     Manufacture of basic chemicals
# 28           2011                     Manufacture of basic chemicals
# 29           2011                     Manufacture of basic chemicals
# ...           ...                                                ...
# 11844        0220                                            Logging
# 11845        0220                                            Logging
# 11846        0220                                            Logging
# 11847        0220                                            Logging
# 11848        1311         Preparation and spinning of textile fibres
# 11849        1311         Preparation and spinning of textile fibres
# 11850        1311         Preparation and spinning of textile fibres
# 11851        1311         Preparation and spinning of textile fibres
# 11852        1050                      Manufacture of dairy products
# 11853        1050                      Manufacture of dairy products
# 11854        2023  Manufacture of soap and detergents, cleaning a...
# 11855        2023  Manufacture of soap and detergents, cleaning a...
# 11856        2023  Manufacture of soap and detergents, cleaning a...
# 11857        2023  Manufacture of soap and detergents, cleaning a...
# 11858        2592         Treatment and coating of metals; machining
# 11859        2592         Treatment and coating of metals; machining
# 11860        2592         Treatment and coating of metals; machining
# 11861        2592         Treatment and coating of metals; machining
# 11862        2592         Treatment and coating of metals; machining
# 11863        2592         Treatment and coating of metals; machining
# 11864        2011                     Manufacture of basic chemicals
# 11865        2011                     Manufacture of basic chemicals
# 11866        2011                     Manufacture of basic chemicals
# 11867        2011                     Manufacture of basic chemicals
# 11868        2011                     Manufacture of basic chemicals
# 11869        2011                     Manufacture of basic chemicals
# 11870        0729             Mining of other non-ferrous metal ores
# 11871        2011                     Manufacture of basic chemicals
# 11872        2011                     Manufacture of basic chemicals
# 11873        0113  Growing of vegetables and melons, roots and tu...
#
#                                             activityName geography  \
# 0                1,1-difluoroethane production, HFC-152a       GLO
# 1                1,1-difluoroethane production, HFC-152a        US
# 2      1,1-dimethylcyclopentane to generic market for...       GLO
# 3                                  1-propanol production       GLO
# 4                                  1-propanol production       RER
# 5      2,3-dimethylbutan to generic market for solven...       GLO
# 6                          2,4-dichlorophenol production       GLO
# 7                          2,4-dichlorophenol production       RER
# 8                         2,4-dichlorotoluene production       GLO
# 9                         2,4-dichlorotoluene production       RER
# 10           2-butanol production by hydration of butene       GLO
# 11           2-butanol production by hydration of butene       RER
# 12                         2-methyl-2-butanol production       GLO
# 13                         2-methyl-2-butanol production       RER
# 14     2-methylpentane to generic market for solvent,...       GLO
# 15                             2-nitroaniline production       GLO
# 16                             2-nitroaniline production       RER
# 17                                2-pyridinol production       GLO
# 18                                2-pyridinol production       RER
# 19                   3-methyl-1-butyl acetate production       GLO
# 20                   3-methyl-1-butyl acetate production       RER
# 21                       4-methyl-2-pentanone production       GLO
# 22                       4-methyl-2-pentanone production       RER
# 23                   4-tert-butylbenzaldehyde production       GLO
# 24                   4-tert-butylbenzaldehyde production       RER
# 25                        4-tert-butyltoluene production       GLO
# 26                        4-tert-butyltoluene production       RER
# 27                             Brown-Schlesinger process       GLO
# 28                                       DTPA production       GLO
# 29                                       DTPA production       RER
# ...                                                  ...       ...
# 11844            yarding, mobile cable yarder on trailer       GLO
# 11845            yarding, mobile cable yarder on trailer       RER
# 11846                               yarding, sled yarder       GLO
# 11847                               yarding, sled yarder       RER
# 11848                              yarn production, jute       GLO
# 11849                              yarn production, jute        IN
# 11850                             yarn production, kenaf       GLO
# 11851                             yarn production, kenaf        IN
# 11852                   yogurt production, from cow milk     CA-QC
# 11853                   yogurt production, from cow milk       GLO
# 11854                         zeolite production, powder       GLO
# 11855                         zeolite production, powder       RER
# 11856  zeolite production, slurry, without water, in ...       GLO
# 11857  zeolite production, slurry, without water, in ...       RER
# 11858                                zinc coating, coils       GLO
# 11859                                zinc coating, coils       RER
# 11860                               zinc coating, pieces       GLO
# 11861                               zinc coating, pieces       RER
# 11862       zinc coating, pieces, adjustment per micro-m       GLO
# 11863       zinc coating, pieces, adjustment per micro-m       RER
# 11864                        zinc monosulfate production       GLO
# 11865                        zinc monosulfate production       RER
# 11866                              zinc oxide production       GLO
# 11867                              zinc oxide production       RER
# 11868                            zinc sulfide production       GLO
# 11869                            zinc sulfide production       RER
# 11870                           zinc-lead mine operation       GLO
# 11871                         zirconium oxide production        AU
# 11872                         zirconium oxide production       GLO
# 11873                                zucchini production       GLO
#
#                                        reference product            status  \
# 0                           1,1-difluoroethane, HFC-152a  in both versions
# 1                           1,1-difluoroethane, HFC-152a  in both versions
# 2                               1,1-dimethylcyclopentane  in both versions
# 3                                             1-propanol  in both versions
# 4                                             1-propanol  in both versions
# 5                                      2,3-dimethylbutan  in both versions
# 6                                     2,4-dichlorophenol  in both versions
# 7                                     2,4-dichlorophenol  in both versions
# 8                                    2,4-dichlorotoluene  in both versions
# 9                                    2,4-dichlorotoluene  in both versions
# 10                                             2-butanol  in both versions
# 11                                             2-butanol  in both versions
# 12                                    2-methyl-2-butanol  in both versions
# 13                                    2-methyl-2-butanol  in both versions
# 14                                       2-methylpentane  in both versions
# 15                                        2-nitroaniline  in both versions
# 16                                        2-nitroaniline  in both versions
# 17                                           2-pyridinol  in both versions
# 18                                           2-pyridinol  in both versions
# 19                              3-methyl-1-butyl acetate  in both versions
# 20                              3-methyl-1-butyl acetate  in both versions
# 21                                  4-methyl-2-pentanone  in both versions
# 22                                  4-methyl-2-pentanone  in both versions
# 23                              4-tert-butylbenzaldehyde  in both versions
# 24                              4-tert-butylbenzaldehyde  in both versions
# 25                                   4-tert-butyltoluene  in both versions
# 26                                   4-tert-butyltoluene  in both versions
# 27                             sodium tetrahydridoborate  in both versions
# 28              DTPA, diethylenetriaminepentaacetic acid  in both versions
# 29              DTPA, diethylenetriaminepentaacetic acid  in both versions
# ...                                                  ...               ...
# 11844                                      cable yarding  in both versions
# 11845                                      cable yarding  in both versions
# 11846                                      cable yarding  in both versions
# 11847                                      cable yarding  in both versions
# 11848                                         yarn, jute  in both versions
# 11849                                         yarn, jute  in both versions
# 11850                                        yarn, kenaf  in both versions
# 11851                                        yarn, kenaf  in both versions
# 11852                              yogurt, from cow milk  in both versions
# 11853                              yogurt, from cow milk  in both versions
# 11854                                    zeolite, powder  in both versions
# 11855                                    zeolite, powder  in both versions
# 11856  zeolite, slurry, without water, in 50% solutio...  in both versions
# 11857  zeolite, slurry, without water, in 50% solutio...  in both versions
# 11858                                   zinc coat, coils  in both versions
# 11859                                   zinc coat, coils  in both versions
# 11860                                  zinc coat, pieces  in both versions
# 11861                                  zinc coat, pieces  in both versions
# 11862          zinc coat, pieces, adjustment per micro-m  in both versions
# 11863          zinc coat, pieces, adjustment per micro-m  in both versions
# 11864                                   zinc monosulfate  in both versions
# 11865                                   zinc monosulfate  in both versions
# 11866                                         zinc oxide  in both versions
# 11867                                         zinc oxide  in both versions
# 11868                                       zinc sulfide  in both versions
# 11869                                       zinc sulfide  in both versions
# 11870                                   zinc concentrate  in both versions
# 11871                                    zirconium oxide  in both versions
# 11872                                    zirconium oxide  in both versions
# 11873                                           zucchini  in both versions
#
#            time period previous       time period current new time period  \
# 0      2005-01-01 to 2006-12-31  2005-01-01 to 2006-12-31              no
# 1      2005-01-01 to 2006-12-31  2005-01-01 to 2006-12-31              no
# 2      2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 3      1998-01-01 to 2006-12-31  1998-01-01 to 2006-12-31              no
# 4      1998-01-01 to 2006-12-31  1998-01-01 to 2006-12-31              no
# 5      2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 6      2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 7      2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 8      2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 9      2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 10     1981-01-01 to 2005-12-31  1981-01-01 to 2005-12-31              no
# 11     1981-01-01 to 2005-12-31  1981-01-01 to 2005-12-31              no
# 12     1989-01-01 to 2006-12-31  1989-01-01 to 2006-12-31              no
# 13     1989-01-01 to 2006-12-31  1989-01-01 to 2006-12-31              no
# 14     2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 15     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 16     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 17     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 18     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 19     1989-01-01 to 2006-12-31  1989-01-01 to 2006-12-31              no
# 20     1989-01-01 to 2006-12-31  1989-01-01 to 2006-12-31              no
# 21     1998-01-01 to 2006-12-31  1998-01-01 to 2006-12-31              no
# 22     1998-01-01 to 2006-12-31  1998-01-01 to 2006-12-31              no
# 23     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 24     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 25     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 26     2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
# 27     2000-01-01 to 2006-12-31  2000-01-01 to 2006-12-31              no
# 28     2000-01-01 to 2000-12-31  2000-01-01 to 2000-12-31              no
# 29     2000-01-01 to 2000-12-31  2000-01-01 to 2000-12-31              no
# ...                         ...                       ...             ...
# 11844  2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 11845  2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 11846  2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 11847  2012-01-01 to 2012-12-31  2012-01-01 to 2012-12-31              no
# 11848  2003-01-01 to 2007-12-31  2003-01-01 to 2007-12-31              no
# 11849  2003-01-01 to 2007-12-31  2003-01-01 to 2007-12-31              no
# 11850  2003-01-01 to 2007-12-31  2003-01-01 to 2007-12-31              no
# 11851  2003-01-01 to 2007-12-31  2003-01-01 to 2007-12-31              no
# 11852  2010-01-01 to 2012-12-31  2010-01-01 to 2012-12-31              no
# 11853  2010-01-01 to 2012-12-31  2010-01-01 to 2012-12-31              no
# 11854  1990-01-01 to 1995-12-31  1990-01-01 to 1995-12-31              no
# 11855  1990-01-01 to 1995-12-31  1990-01-01 to 1995-12-31              no
# 11856  1990-01-01 to 1995-12-31  1990-01-01 to 1995-12-31              no
# 11857  1990-01-01 to 1995-12-31  1990-01-01 to 1995-12-31              no
# 11858  1996-01-01 to 2002-12-31  1996-01-01 to 2002-12-31              no
# 11859  1996-01-01 to 2002-12-31  1996-01-01 to 2002-12-31              no
# 11860  1996-01-01 to 2002-12-31  1996-01-01 to 2002-12-31              no
# 11861  1996-01-01 to 2002-12-31  1996-01-01 to 2002-12-31              no
# 11862  1996-01-01 to 2002-12-31  1996-01-01 to 2002-12-31              no
# 11863  1996-01-01 to 2002-12-31  1996-01-01 to 2002-12-31              no
# 11864  2005-01-01 to 2007-12-31  2005-01-01 to 2007-12-31              no
# 11865  2005-01-01 to 2007-12-31  2005-01-01 to 2007-12-31              no
# 11866  2005-01-01 to 2007-12-31  2005-01-01 to 2007-12-31              no
# 11867  2005-01-01 to 2007-12-31  2005-01-01 to 2007-12-31              no
# 11868  2005-01-01 to 2007-12-31  2005-01-01 to 2007-12-31              no
# 11869  2005-01-01 to 2007-12-31  2005-01-01 to 2007-12-31              no
# 11870  1994-01-01 to 2003-12-31  1994-01-01 to 2003-12-31              no
# 11871  2000-01-01 to 2005-12-31  2000-01-01 to 2005-12-31              no
# 11872  2000-01-01 to 2005-12-31  2000-01-01 to 2005-12-31              no
# 11873  2010-01-01 to 2010-12-31  2010-01-01 to 2010-12-31              no
#
#       Technology Level previous Technology Level current  \
# 0                       Current                  Current
# 1                       Current                  Current
# 2                       Current                  Current
# 3                       Current                  Current
# 4                       Current                  Current
# 5                       Current                  Current
# 6                       Current                  Current
# 7                       Current                  Current
# 8                       Current                  Current
# 9                       Current                  Current
# 10                      Current                  Current
# 11                      Current                  Current
# 12                      Current                  Current
# 13                      Current                  Current
# 14                      Current                  Current
# 15                      Current                  Current
# 16                      Current                  Current
# 17                      Current                  Current
# 18                      Current                  Current
# 19                      Current                  Current
# 20                      Current                  Current
# 21                      Current                  Current
# 22                      Current                  Current
# 23                      Current                  Current
# 24                      Current                  Current
# 25                      Current                  Current
# 26                      Current                  Current
# 27                      Current                  Current
# 28                      Current                  Current
# 29                      Current                  Current
# ...                         ...                      ...
# 11844                   Current                  Current
# 11845                   Current                  Current
# 11846                   Current                  Current
# 11847                   Current                  Current
# 11848                   Current                  Current
# 11849                   Current                  Current
# 11850                   Current                  Current
# 11851                   Current                  Current
# 11852                   Current                  Current
# 11853                   Current                  Current
# 11854                   Current                  Current
# 11855                   Current                  Current
# 11856                   Current                  Current
# 11857                   Current                  Current
# 11858                   Current                  Current
# 11859                   Current                  Current
# 11860                   Current                  Current
# 11861                   Current                  Current
# 11862                   Current                  Current
# 11863                   Current                  Current
# 11864                   Current                  Current
# 11865                   Current                  Current
# 11866                   Current                  Current
# 11867                   Current                  Current
# 11868                   Current                  Current
# 11869                   Current                  Current
# 11870                   Current                  Current
# 11871                   Current                  Current
# 11872                   Current                  Current
# 11873                   Current                  Current
#
#       Technology Level updated quantitative change      Tags current  \
# 0                           no                  no  ConvertedDataset
# 1                           no                  no  ConvertedDataset
# 2                           no                  no               NaN
# 3                           no                  no  ConvertedDataset
# 4                           no                  no  ConvertedDataset
# 5                           no                  no               NaN
# 6                           no                  no               NaN
# 7                           no                  no               NaN
# 8                           no                  no               NaN
# 9                           no                  no               NaN
# 10                          no                  no  ConvertedDataset
# 11                          no                  no  ConvertedDataset
# 12                          no                  no  ConvertedDataset
# 13                          no                  no  ConvertedDataset
# 14                          no                  no               NaN
# 15                          no                  no               NaN
# 16                          no                  no               NaN
# 17                          no                  no               NaN
# 18                          no                  no               NaN
# 19                          no                  no  ConvertedDataset
# 20                          no                  no  ConvertedDataset
# 21                          no                  no  ConvertedDataset
# 22                          no                  no               NaN
# 23                          no                  no               NaN
# 24                          no                  no               NaN
# 25                          no                  no               NaN
# 26                          no                  no               NaN
# 27                          no                  no  ConvertedDataset
# 28                          no                  no  ConvertedDataset
# 29                          no                  no  ConvertedDataset
# ...                        ...                 ...               ...
# 11844                       no                  no               NaN
# 11845                       no                  no               NaN
# 11846                       no                  no               NaN
# 11847                       no                  no               NaN
# 11848                       no                  no  ConvertedDataset
# 11849                       no                  no  ConvertedDataset
# 11850                       no                  no  ConvertedDataset
# 11851                       no                  no  ConvertedDataset
# 11852                       no                  no               NaN
# 11853                       no                  no               NaN
# 11854                       no                  no  ConvertedDataset
# 11855                       no                  no  ConvertedDataset
# 11856                       no                  no  ConvertedDataset
# 11857                       no                  no  ConvertedDataset
# 11858                       no                  no  ConvertedDataset
# 11859                       no                  no  ConvertedDataset
# 11860                       no                  no  ConvertedDataset
# 11861                       no                  no  ConvertedDataset
# 11862                       no                  no  ConvertedDataset
# 11863                       no                  no  ConvertedDataset
# 11864                       no                  no  ConvertedDataset
# 11865                       no                  no  ConvertedDataset
# 11866                       no                  no  ConvertedDataset
# 11867                       no                  no  ConvertedDataset
# 11868                       no                  no  ConvertedDataset
# 11869                       no                  no  ConvertedDataset
# 11870                       no                 yes  ConvertedDataset
# 11871                       no                  no  ConvertedDataset
# 11872                       no                  no  ConvertedDataset
# 11873                       no                 yes               NaN
#
#       activityName renamed activityName previous reference product renamed  \
# 0                       no                   NaN                        no
# 1                       no                   NaN                        no
# 2                       no                   NaN                        no
# 3                       no                   NaN                        no
# 4                       no                   NaN                        no
# 5                       no                   NaN                        no
# 6                       no                   NaN                        no
# 7                       no                   NaN                        no
# 8                       no                   NaN                        no
# 9                       no                   NaN                        no
# 10                      no                   NaN                        no
# 11                      no                   NaN                        no
# 12                      no                   NaN                        no
# 13                      no                   NaN                        no
# 14                      no                   NaN                        no
# 15                      no                   NaN                        no
# 16                      no                   NaN                        no
# 17                      no                   NaN                        no
# 18                      no                   NaN                        no
# 19                      no                   NaN                        no
# 20                      no                   NaN                        no
# 21                      no                   NaN                        no
# 22                      no                   NaN                        no
# 23                      no                   NaN                        no
# 24                      no                   NaN                        no
# 25                      no                   NaN                        no
# 26                      no                   NaN                        no
# 27                      no                   NaN                        no
# 28                      no                   NaN                        no
# 29                      no                   NaN                        no
# ...                    ...                   ...                       ...
# 11844                   no                   NaN                        no
# 11845                   no                   NaN                        no
# 11846                   no                   NaN                        no
# 11847                   no                   NaN                        no
# 11848                   no                   NaN                        no
# 11849                   no                   NaN                        no
# 11850                   no                   NaN                        no
# 11851                   no                   NaN                        no
# 11852                   no                   NaN                        no
# 11853                   no                   NaN                        no
# 11854                   no                   NaN                        no
# 11855                   no                   NaN                        no
# 11856                   no                   NaN                        no
# 11857                   no                   NaN                        no
# 11858                   no                   NaN                        no
# 11859                   no                   NaN                        no
# 11860                   no                   NaN                        no
# 11861                   no                   NaN                        no
# 11862                   no                   NaN                        no
# 11863                   no                   NaN                        no
# 11864                   no                   NaN                        no
# 11865                   no                   NaN                        no
# 11866                   no                   NaN                        no
# 11867                   no                   NaN                        no
# 11868                   no                   NaN                        no
# 11869                   no                   NaN                        no
# 11870                   no                   NaN                        no
# 11871                   no                   NaN                        no
# 11872                   no                   NaN                        no
# 11873                   no                   NaN                        no
#
#       reference product previous
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 11844                        NaN
# 11845                        NaN
# 11846                        NaN
# 11847                        NaN
# 11848                        NaN
# 11849                        NaN
# 11850                        NaN
# 11851                        NaN
# 11852                        NaN
# 11853                        NaN
# 11854                        NaN
# 11855                        NaN
# 11856                        NaN
# 11857                        NaN
# 11858                        NaN
# 11859                        NaN
# 11860                        NaN
# 11861                        NaN
# 11862                        NaN
# 11863                        NaN
# 11864                        NaN
# 11865                        NaN
# 11866                        NaN
# 11867                        NaN
# 11868                        NaN
# 11869                        NaN
# 11870                        NaN
# 11871                        NaN
# 11872                        NaN
# 11873                        NaN
#
# [11874 rows x 18 columns]

# %% [markdown]
# Let's get a list of the activities which were renamed, but are otherwise not substantially changed. This will be from 3.1 to 3.2; we will need to combine this with the changes from 3.2 to 3.3.

# %%
renamed_mask = (overview['reference product renamed'] == 'yes') | (overview['activityName renamed'] == 'yes')
renamed_mask.sum()
# Out:
# 172

# %% [markdown]
# Construct dictionary mapping names, reference products, and locations.
#
# Need to be clever and handle `NaN` in some places where the reference product or activity name didn't change.
#
# Also, change 'GLO' to 'RoW' where needed.
#
# Will drop renamings (forcing a manual correction) if the 3.2 activity is not also in 3.3.

# %%
renamed_31_33 = {}

for _, row in overview[renamed_mask].iterrows():
    value = [row['activityName'], row['reference product'], row['geography']]

    if isinstance(row['activityName previous'], str):
        old_name = row['activityName previous']
    else:
        old_name = row['activityName']
    if isinstance(row['reference product previous'], str):
        old_rp = row['reference product previous']
    else:
        old_rp = row['reference product']
    key = [old_name, old_rp, row['geography']]
    
    if tuple(key) not in data_31 and key[2] == 'GLO':
        key[2] = 'RoW'
    if tuple(value) not in data_33 and value[2] == 'GLO':
        value[2] = 'RoW'
    
    if tuple(key) in data_31 and tuple(value) in data_33:
        renamed_31_33[tuple(key)] = tuple(value)

# %%
renamed_31_33
# Out:
# {('beam, hardwood, raw, air drying',
#   'sawnwood, beam, hardwood, raw, air dried',
#   'CH'): ('beam, hardwood, raw, air drying to u=20%',
#   'sawnwood, beam, hardwood, raw, dried (u=20%)',
#   'CH'),
#  ('beam, hardwood, raw, air drying',
#   'sawnwood, beam, hardwood, raw, air dried',
#   'RoW'): ('beam, hardwood, raw, air drying to u=20%',
#   'sawnwood, beam, hardwood, raw, dried (u=20%)',
#   'RoW'),
#  ('beam, hardwood, raw, kiln drying',
#   'sawnwood, beam, hardwood, raw, kiln dried',
#   'CH'): ('beam, hardwood, raw, kiln drying to u=10%',
#   'sawnwood, beam, hardwood, raw, dried (u=10%)',
#   'CH'),
#  ('beam, hardwood, raw, kiln drying',
#   'sawnwood, beam, hardwood, raw, kiln dried',
#   'RoW'): ('beam, hardwood, raw, kiln drying to u=10%',
#   'sawnwood, beam, hardwood, raw, dried (u=10%)',
#   'RoW'),
#  ('beam, softwood, raw, air drying',
#   'sawnwood, beam, softwood, raw, air dried',
#   'CH'): ('beam, softwood, raw, air drying to u=20%',
#   'sawnwood, beam, softwood, raw, dried (u=20%)',
#   'CH'),
#  ('beam, softwood, raw, air drying',
#   'sawnwood, beam, softwood, raw, air dried',
#   'RoW'): ('beam, softwood, raw, air drying to u=20%',
#   'sawnwood, beam, softwood, raw, dried (u=20%)',
#   'RoW'),
#  ('beam, softwood, raw, kiln drying',
#   'sawnwood, beam, softwood, raw, kiln dried',
#   'CH'): ('beam, softwood, raw, kiln drying to u=10%',
#   'sawnwood, beam, softwood, raw, dried (u=10%)',
#   'CH'),
#  ('beam, softwood, raw, kiln drying',
#   'sawnwood, beam, softwood, raw, kiln dried',
#   'RoW'): ('beam, softwood, raw, kiln drying to u=10%',
#   'sawnwood, beam, softwood, raw, dried (u=10%)',
#   'RoW'),
#  ('board, hardwood, raw, air drying',
#   'sawnwood, board, hardwood, raw, air dried',
#   'CH'): ('board, hardwood, raw, air drying to u=20%',
#   'sawnwood, board, hardwood, raw, dried (u=20%)',
#   'CH'),
#  ('board, hardwood, raw, air drying',
#   'sawnwood, board, hardwood, raw, air dried',
#   'RoW'): ('board, hardwood, raw, air drying to u=20%',
#   'sawnwood, board, hardwood, raw, dried (u=20%)',
#   'RoW'),
#  ('board, hardwood, raw, kiln drying',
#   'sawnwood, board, hardwood, raw, kiln dried',
#   'CH'): ('board, hardwood, raw, kiln drying to u=10%',
#   'sawnwood, board, hardwood, raw, dried (u=10%)',
#   'CH'),
#  ('board, hardwood, raw, kiln drying',
#   'sawnwood, board, hardwood, raw, kiln dried',
#   'RoW'): ('board, hardwood, raw, kiln drying to u=10%',
#   'sawnwood, board, hardwood, raw, dried (u=10%)',
#   'RoW'),
#  ('board, softwood, raw, air drying',
#   'sawnwood, board, softwood, raw, air dried',
#   'CH'): ('board, softwood, raw, air drying to u=20%',
#   'sawnwood, board, softwood, raw, dried (u=20%)',
#   'CH'),
#  ('board, softwood, raw, air drying',
#   'sawnwood, board, softwood, raw, air dried',
#   'RoW'): ('board, softwood, raw, air drying to u=20%',
#   'sawnwood, board, softwood, raw, dried (u=20%)',
#   'RoW'),
#  ('board, softwood, raw, kiln drying',
#   'sawnwood, board, softwood, raw, kiln dried',
#   'CH'): ('board, softwood, raw, kiln drying to u=10%',
#   'sawnwood, board, softwood, raw, dried (u=10%)',
#   'CH'),
#  ('board, softwood, raw, kiln drying',
#   'sawnwood, board, softwood, raw, kiln dried',
#   'RoW'): ('board, softwood, raw, kiln drying to u=10%',
#   'sawnwood, board, softwood, raw, dried (u=10%)',
#   'RoW'),
#  ('brick production', 'brick', 'RER'): ('clay brick production',
#   'clay brick',
#   'RER'),
#  ('brick production', 'brick', 'RoW'): ('clay brick production',
#   'clay brick',
#   'RoW'),
#  ('brick shale production', 'brick shale', 'CA-QC'): ('shale brick production',
#   'shale brick',
#   'CA-QC'),
#  ('brick shale production', 'brick shale', 'RoW'): ('shale brick production',
#   'shale brick',
#   'RoW'),
#  ('diesel, burned in diesel-electric generating set',
#   'diesel, burned in diesel-electric generating set',
#   'GLO'): ('diesel, burned in diesel-electric generating set, 10MW',
#   'diesel, burned in diesel-electric generating set, 10MW',
#   'GLO'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'AT'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'AT'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'BE'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'BE'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'BG'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'BG'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-AB'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CA-AB'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-NB'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CA-NB'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-NS'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CA-NS'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-ON'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CA-ON'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-PE'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CA-PE'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CH'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CH'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CZ'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'CZ'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'DE'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'DE'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'DK'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'DK'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'ES'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'ES'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'FI'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'FI'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'FR'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'FR'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'GB'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'GB'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'HU'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'HU'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'IT'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'IT'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'JP'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'JP'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'KR'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'KR'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'LU'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'LU'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'NL'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'NL'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'NO'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'NO'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'PL'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'PL'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'PT'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'PT'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'RU'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'RU'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'RoW'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'RoW'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'SE'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'SE'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'SK'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'SK'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'TR'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'TR'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'TW'): ('electricity, from municipal waste incineration to generic market for electricity, medium voltage',
#   'electricity, medium voltage',
#   'TW'),
#  ('lath, hardwood, raw, air drying',
#   'sawnwood, lath, hardwood, raw, air dried',
#   'CH'): ('lath, hardwood, raw, air drying to u=20%',
#   'sawnwood, lath, hardwood, raw, dried (u=20%)',
#   'CH'),
#  ('lath, hardwood, raw, air drying',
#   'sawnwood, lath, hardwood, raw, air dried',
#   'RoW'): ('lath, hardwood, raw, air drying to u=20%',
#   'sawnwood, lath, hardwood, raw, dried (u=20%)',
#   'RoW'),
#  ('lath, hardwood, raw, kiln drying',
#   'sawnwood, lath, hardwood, raw, kiln dried',
#   'CH'): ('lath, hardwood, raw, kiln drying to u=10%',
#   'sawnwood, lath, hardwood, raw, dried (u=10%)',
#   'CH'),
#  ('lath, hardwood, raw, kiln drying',
#   'sawnwood, lath, hardwood, raw, kiln dried',
#   'RoW'): ('lath, hardwood, raw, kiln drying to u=10%',
#   'sawnwood, lath, hardwood, raw, dried (u=10%)',
#   'RoW'),
#  ('lath, softwood, raw, air drying',
#   'sawnwood, lath, softwood, raw, air dried',
#   'CH'): ('lath, softwood, raw, air drying to u=20%',
#   'sawnwood, lath, softwood, raw, dried (u=20%)',
#   'CH'),
#  ('lath, softwood, raw, air drying',
#   'sawnwood, lath, softwood, raw, air dried',
#   'RoW'): ('lath, softwood, raw, air drying to u=20%',
#   'sawnwood, lath, softwood, raw, dried (u=20%)',
#   'RoW'),
#  ('lath, softwood, raw, kiln drying',
#   'sawnwood, lath, softwood, raw, kiln dried',
#   'CH'): ('lath, softwood, raw, kiln drying to u=10%',
#   'sawnwood, lath, softwood, raw, dried (u=10%)',
#   'CH'),
#  ('lath, softwood, raw, kiln drying',
#   'sawnwood, lath, softwood, raw, kiln dried',
#   'RoW'): ('lath, softwood, raw, kiln drying to u=10%',
#   'sawnwood, lath, softwood, raw, dried (u=10%)',
#   'RoW'),
#  ('market for brick', 'brick', 'GLO'): ('market for clay brick',
#   'clay brick',
#   'GLO'),
#  ('market for brick shale', 'brick shale', 'GLO'): ('market for shale brick',
#   'shale brick',
#   'GLO'),
#  ('market for diesel, burned in diesel-electric generating set',
#   'diesel, burned in diesel-electric generating set',
#   'GLO'): ('market for diesel, burned in diesel-electric generating set, 10MW',
#   'diesel, burned in diesel-electric generating set, 10MW',
#   'GLO'),
#  ('market for poor concrete',
#   'poor concrete',
#   'GLO'): ('market for lean concrete', 'lean concrete', 'RoW'),
#  ('market for sawnwood, beam, hardwood, air dried, planed',
#   'sawnwood, beam, hardwood, air dried, planed',
#   'GLO'): ('market for sawnwood, beam, hardwood, dried (u=20%), planed',
#   'sawnwood, beam, hardwood, dried (u=20%), planed',
#   'GLO'),
#  ('market for sawnwood, beam, hardwood, kiln dried, planed',
#   'sawnwood, beam, hardwood, kiln dried, planed',
#   'GLO'): ('market for sawnwood, beam, hardwood, dried (u=10%), planed',
#   'sawnwood, beam, hardwood, dried (u=10%), planed',
#   'GLO'),
#  ('market for sawnwood, beam, hardwood, raw, air dried',
#   'sawnwood, beam, hardwood, raw, air dried',
#   'GLO'): ('market for sawnwood, beam, hardwood, raw, dried (u=20%)',
#   'sawnwood, beam, hardwood, raw, dried (u=20%)',
#   'GLO'),
#  ('market for sawnwood, beam, hardwood, raw, kiln dried',
#   'sawnwood, beam, hardwood, raw, kiln dried',
#   'GLO'): ('market for sawnwood, beam, hardwood, raw, dried (u=10%)',
#   'sawnwood, beam, hardwood, raw, dried (u=10%)',
#   'GLO'),
#  ('market for sawnwood, beam, softwood, air dried, planed',
#   'sawnwood, beam, softwood, air dried, planed',
#   'GLO'): ('market for sawnwood, beam, softwood, dried (u=20%), planed',
#   'sawnwood, beam, softwood, dried (u=20%), planed',
#   'GLO'),
#  ('market for sawnwood, beam, softwood, kiln dried, planed',
#   'sawnwood, beam, softwood, kiln dried, planed',
#   'GLO'): ('market for sawnwood, beam, softwood, dried (u=10%), planed',
#   'sawnwood, beam, softwood, dried (u=10%), planed',
#   'GLO'),
#  ('market for sawnwood, beam, softwood, raw, air dried',
#   'sawnwood, beam, softwood, raw, air dried',
#   'GLO'): ('market for sawnwood, beam, softwood, raw, dried (u=20%)',
#   'sawnwood, beam, softwood, raw, dried (u=20%)',
#   'GLO'),
#  ('market for sawnwood, beam, softwood, raw, kiln dried',
#   'sawnwood, beam, softwood, raw, kiln dried',
#   'GLO'): ('market for sawnwood, beam, softwood, raw, dried (u=10%)',
#   'sawnwood, beam, softwood, raw, dried (u=10%)',
#   'GLO'),
#  ('market for sawnwood, board, hardwood, air dried, planed',
#   'sawnwood, board, hardwood, air dried, planed',
#   'GLO'): ('market for sawnwood, board, hardwood, dried (u=20%), planed',
#   'sawnwood, board, hardwood, dried (u=20%), planed',
#   'GLO'),
#  ('market for sawnwood, board, hardwood, kiln dried, planed',
#   'sawnwood, board, hardwood, kiln dried, planed',
#   'GLO'): ('market for sawnwood, board, hardwood, dried (u=10%), planed',
#   'sawnwood, board, hardwood, dried (u=10%), planed',
#   'GLO'),
#  ('market for sawnwood, board, hardwood, raw, air dried',
#   'sawnwood, board, hardwood, raw, air dried',
#   'GLO'): ('market for sawnwood, board, hardwood, raw, dried (u=20%)',
#   'sawnwood, board, hardwood, raw, dried (u=20%)',
#   'GLO'),
#  ('market for sawnwood, board, hardwood, raw, kiln dried',
#   'sawnwood, board, hardwood, raw, kiln dried',
#   'GLO'): ('market for sawnwood, board, hardwood, raw, dried (u=10%)',
#   'sawnwood, board, hardwood, raw, dried (u=10%)',
#   'GLO'),
#  ('market for sawnwood, board, softwood, air dried, planed',
#   'sawnwood, board, softwood, air dried, planed',
#   'GLO'): ('market for sawnwood, board, softwood, dried (u=20%), planed',
#   'sawnwood, board, softwood, dried (u=20%), planed',
#   'GLO'),
#  ('market for sawnwood, board, softwood, kiln dried, planed',
#   'sawnwood, board, softwood, kiln dried, planed',
#   'GLO'): ('market for sawnwood, board, softwood, dried (u=10%), planed',
#   'sawnwood, board, softwood, dried (u=10%), planed',
#   'GLO'),
#  ('market for sawnwood, board, softwood, raw, air dried',
#   'sawnwood, board, softwood, raw, air dried',
#   'GLO'): ('market for sawnwood, board, softwood, raw, dried (u=20%)',
#   'sawnwood, board, softwood, raw, dried (u=20%)',
#   'GLO'),
#  ('market for sawnwood, board, softwood, raw, kiln dried',
#   'sawnwood, board, softwood, raw, kiln dried',
#   'GLO'): ('market for sawnwood, board, softwood, raw, dried (u=10%)',
#   'sawnwood, board, softwood, raw, dried (u=10%)',
#   'GLO'),
#  ('market for sawnwood, hardwood, air dried, planed',
#   'sawnwood, hardwood, air dried, planed',
#   'RER'): ('market for sawnwood, hardwood, dried (u=20%), planed',
#   'sawnwood, hardwood, dried (u=20%), planed',
#   'RER'),
#  ('market for sawnwood, hardwood, air dried, planed',
#   'sawnwood, hardwood, air dried, planed',
#   'RoW'): ('market for sawnwood, hardwood, dried (u=20%), planed',
#   'sawnwood, hardwood, dried (u=20%), planed',
#   'RoW'),
#  ('market for sawnwood, hardwood, kiln dried, planed',
#   'sawnwood, hardwood, kiln dried, planed',
#   'RER'): ('market for sawnwood, hardwood, dried (u=10%), planed',
#   'sawnwood, hardwood, dried (u=10%), planed',
#   'RER'),
#  ('market for sawnwood, hardwood, kiln dried, planed',
#   'sawnwood, hardwood, kiln dried, planed',
#   'RoW'): ('market for sawnwood, hardwood, dried (u=10%), planed',
#   'sawnwood, hardwood, dried (u=10%), planed',
#   'RoW'),
#  ('market for sawnwood, hardwood, raw, air dried',
#   'sawnwood, hardwood, raw, air dried',
#   'RER'): ('market for sawnwood, hardwood, raw, dried (u=20%)',
#   'sawnwood, hardwood, raw, dried (u=20%)',
#   'RER'),
#  ('market for sawnwood, hardwood, raw, air dried',
#   'sawnwood, hardwood, raw, air dried',
#   'RoW'): ('market for sawnwood, hardwood, raw, dried (u=20%)',
#   'sawnwood, hardwood, raw, dried (u=20%)',
#   'RoW'),
#  ('market for sawnwood, hardwood, raw, debarked',
#   'sawnwood, hardwood, raw, debarked',
#   'RoW'): ('market for sawnwood, hardwood, raw',
#   'sawnwood, hardwood, raw',
#   'GLO'),
#  ('market for sawnwood, hardwood, raw, kiln dried',
#   'sawnwood, hardwood, raw, kiln dried',
#   'RER'): ('market for sawnwood, hardwood, raw, dried (u=10%)',
#   'sawnwood, hardwood, raw, dried (u=10%)',
#   'RER'),
#  ('market for sawnwood, hardwood, raw, kiln dried',
#   'sawnwood, hardwood, raw, kiln dried',
#   'RoW'): ('market for sawnwood, hardwood, raw, dried (u=10%)',
#   'sawnwood, hardwood, raw, dried (u=10%)',
#   'RoW'),
#  ('market for sawnwood, lath, hardwood, raw, air dried',
#   'sawnwood, lath, hardwood, raw, air dried',
#   'GLO'): ('market for sawnwood, lath, hardwood, raw, dried (u=20%)',
#   'sawnwood, lath, hardwood, raw, dried (u=20%)',
#   'GLO'),
#  ('market for sawnwood, lath, hardwood, raw, kiln dried',
#   'sawnwood, lath, hardwood, raw, kiln dried',
#   'GLO'): ('market for sawnwood, lath, hardwood, raw, dried (u=10%)',
#   'sawnwood, lath, hardwood, raw, dried (u=10%)',
#   'GLO'),
#  ('market for sawnwood, lath, softwood, raw, air dried',
#   'sawnwood, lath, softwood, raw, air dried',
#   'GLO'): ('market for sawnwood, lath, softwood, raw, dried (u=20%)',
#   'sawnwood, lath, softwood, raw, dried (u=20%)',
#   'GLO'),
#  ('market for sawnwood, lath, softwood, raw, kiln dried',
#   'sawnwood, lath, softwood, raw, kiln dried',
#   'GLO'): ('market for sawnwood, lath, softwood, raw, dried (u=10%)',
#   'sawnwood, lath, softwood, raw, dried (u=10%)',
#   'GLO'),
#  ('market for sawnwood, softwood, air dried, planed',
#   'sawnwood, softwood, air dried, planed',
#   'RER'): ('market for sawnwood, softwood, dried (u=20%), planed',
#   'sawnwood, softwood, dried (u=20%), planed',
#   'RER'),
#  ('market for sawnwood, softwood, air dried, planed',
#   'sawnwood, softwood, air dried, planed',
#   'RoW'): ('market for sawnwood, softwood, dried (u=20%), planed',
#   'sawnwood, softwood, dried (u=20%), planed',
#   'RoW'),
#  ('market for sawnwood, softwood, kiln dried, planed',
#   'sawnwood, softwood, kiln dried, planed',
#   'RER'): ('market for sawnwood, softwood, dried (u=10%), planed',
#   'sawnwood, softwood, dried (u=10%), planed',
#   'RER'),
#  ('market for sawnwood, softwood, kiln dried, planed',
#   'sawnwood, softwood, kiln dried, planed',
#   'RoW'): ('market for sawnwood, softwood, dried (u=10%), planed',
#   'sawnwood, softwood, dried (u=10%), planed',
#   'RoW'),
#  ('market for sawnwood, softwood, raw, air dried',
#   'sawnwood, softwood, raw, air dried',
#   'RER'): ('market for sawnwood, softwood, raw, dried (u=20%)',
#   'sawnwood, softwood, raw, dried (u=20%)',
#   'RER'),
#  ('market for sawnwood, softwood, raw, air dried',
#   'sawnwood, softwood, raw, air dried',
#   'RoW'): ('market for sawnwood, softwood, raw, dried (u=20%)',
#   'sawnwood, softwood, raw, dried (u=20%)',
#   'RoW'),
#  ('market for sawnwood, softwood, raw, debarked',
#   'sawnwood, softwood, raw, debarked',
#   'GLO'): ('market for sawnwood, softwood, raw',
#   'sawnwood, softwood, raw',
#   'GLO'),
#  ('market for sawnwood, softwood, raw, kiln dried',
#   'sawnwood, softwood, raw, kiln dried',
#   'RER'): ('market for sawnwood, softwood, raw, dried (u=10%)',
#   'sawnwood, softwood, raw, dried (u=10%)',
#   'RER'),
#  ('market for sawnwood, softwood, raw, kiln dried',
#   'sawnwood, softwood, raw, kiln dried',
#   'RoW'): ('market for sawnwood, softwood, raw, dried (u=10%)',
#   'sawnwood, softwood, raw, dried (u=10%)',
#   'RoW'),
#  ('market for shaving, hardwood, measured as dry mass',
#   'shaving, hardwood, measured as dry mass',
#   'GLO'): ('market for shavings, hardwood, measured as dry mass',
#   'shavings, hardwood, measured as dry mass',
#   'GLO'),
#  ('market for shaving, softwood, measured as dry mass',
#   'shaving, softwood, measured as dry mass',
#   'GLO'): ('market for shavings, softwood, measured as dry mass',
#   'shavings, softwood, measured as dry mass',
#   'GLO'),
#  ('market for transport, freight, loryy >32 metric ton, EURO6',
#   'transport, freight, loryy >32 metric ton, EURO6',
#   'GLO'): ('market for transport, freight, lorry >32 metric ton, EURO6',
#   'transport, freight, lorry >32 metric ton, EURO6',
#   'GLO'),
#  ('market for wood preservation, dipping/immersion method, organic solvent-based, indoor use, occasionally wet, as a(...)_1',
#   'wood preservation, dipping/immersion method, organic solvent-based, indoor use, occasionally wet',
#   'GLO'): ('market for wood preservation, dipping/immersion method, organic solvent-based, indoor use, occasionally wet',
#   'wood preservation, dipping/immersion method, organic solvent-based, indoor use, occasionally wet',
#   'GLO'),
#  ('market for wood preservation, dipping/immersion method, organic solvent-based, outdoor use, no ground contact, as(...)_2',
#   'wood preservation, dipping/immersion method, organic solvent-based, outdoor use, no ground contact',
#   'GLO'): ('market for wood preservation, dipping/immersion method, organic solvent-based, outdoor use, no ground contact',
#   'wood preservation, dipping/immersion method, organic solvent-based, outdoor use, no ground contact',
#   'GLO'),
#  ('market for wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact, as(...)_5',
#   'wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact',
#   'GLO'): ('market for wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact',
#   'wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact',
#   'GLO'),
#  ('market for wood preservation, spray tunnel/deluging, organic solvent-based, indoor use, occasionally wet, as amou(...)_6',
#   'wood preservation, spray tunnel/deluging, organic solvent-based, indoor use, occasionally wet',
#   'GLO'): ('market for wood preservation, spray tunnel/deluging, organic solvent-based, indoor use, occasionally wet',
#   'wood preservation, spray tunnel/deluging, organic solvent-based, indoor use, occasionally wet',
#   'GLO'),
#  ('market for wood preservation, spray tunnel/deluging, organic solvent-based, outdoor use, no ground contact, as am(...)_7',
#   'wood preservation, spray tunnel/deluging, organic solvent-based, outdoor use, no ground contact',
#   'GLO'): ('market for wood preservation, spray tunnel/deluging, organic solvent-based, outdoor use, no ground contact',
#   'wood preservation, spray tunnel/deluging, organic solvent-based, outdoor use, no ground contact',
#   'GLO'),
#  ('market for wood preservation, vaccum pressure method, inorganic salt, containing Cr, outdoor use, ground contact,(...)_4',
#   'wood preservation, vaccum pressure method, inorganic salt, containing Cr, outdoor use, ground contact',
#   'GLO'): ('market for wood preservation, vaccum pressure method, inorganic salt, containing Cr, outdoor use, ground contact',
#   'wood preservation, vaccum pressure method, inorganic salt, containing Cr, outdoor use, ground contact',
#   'GLO'),
#  ('market for wood preservation, vacuum pressure method, organic salts, Cr-free, outdoor use, ground contact, as amo(...)_3',
#   'wood preservation, vacuum pressure method, organic salts, Cr-free, outdoor use, ground contact',
#   'GLO'): ('market for wood preservation, vacuum pressure method, organic salts, Cr-free, outdoor use, ground contact',
#   'wood preservation, vacuum pressure method, organic salts, Cr-free, outdoor use, ground contact',
#   'GLO'),
#  ('planing, beam, hardwood, air dried',
#   'sawnwood, beam, hardwood, air dried, planed',
#   'CH'): ('planing, beam, hardwood, u=20%',
#   'sawnwood, beam, hardwood, dried (u=20%), planed',
#   'CH'),
#  ('planing, beam, hardwood, air dried',
#   'sawnwood, beam, hardwood, air dried, planed',
#   'RoW'): ('planing, beam, hardwood, u=20%',
#   'sawnwood, beam, hardwood, dried (u=20%), planed',
#   'RoW'),
#  ('planing, beam, hardwood, kiln dried',
#   'sawnwood, beam, hardwood, kiln dried, planed',
#   'CH'): ('planing, beam, hardwood, u=10%',
#   'sawnwood, beam, hardwood, dried (u=10%), planed',
#   'CH'),
#  ('planing, beam, hardwood, kiln dried',
#   'sawnwood, beam, hardwood, kiln dried, planed',
#   'RoW'): ('planing, beam, hardwood, u=10%',
#   'sawnwood, beam, hardwood, dried (u=10%), planed',
#   'RoW'),
#  ('planing, beam, softwood, air dried',
#   'sawnwood, beam, softwood, air dried, planed',
#   'CH'): ('planing, beam, softwood, u=20%',
#   'sawnwood, beam, softwood, dried (u=20%), planed',
#   'CH'),
#  ('planing, beam, softwood, air dried',
#   'sawnwood, beam, softwood, air dried, planed',
#   'RoW'): ('planing, beam, softwood, u=20%',
#   'sawnwood, beam, softwood, dried (u=20%), planed',
#   'RoW'),
#  ('planing, beam, softwood, kiln dried',
#   'sawnwood, beam, softwood, kiln dried, planed',
#   'CH'): ('planing, beam, softwood, u=10%',
#   'sawnwood, beam, softwood, dried (u=10%), planed',
#   'CH'),
#  ('planing, beam, softwood, kiln dried',
#   'sawnwood, beam, softwood, kiln dried, planed',
#   'RoW'): ('planing, beam, softwood, u=10%',
#   'sawnwood, beam, softwood, dried (u=10%), planed',
#   'RoW'),
#  ('planing, board, hardwood, air dried',
#   'sawnwood, board, hardwood, air dried, planed',
#   'CH'): ('planing, board, hardwood, u=20%',
#   'sawnwood, board, hardwood, dried (u=20%), planed',
#   'CH'),
#  ('planing, board, hardwood, air dried',
#   'sawnwood, board, hardwood, air dried, planed',
#   'RoW'): ('planing, board, hardwood, u=20%',
#   'sawnwood, board, hardwood, dried (u=20%), planed',
#   'RoW'),
#  ('planing, board, hardwood, kiln dried',
#   'sawnwood, board, hardwood, kiln dried, planed',
#   'CH'): ('planing, board, hardwood, u=10%',
#   'sawnwood, board, hardwood, dried (u=10%), planed',
#   'CH'),
#  ('planing, board, hardwood, kiln dried',
#   'sawnwood, board, hardwood, kiln dried, planed',
#   'RoW'): ('planing, board, hardwood, u=10%',
#   'sawnwood, board, hardwood, dried (u=10%), planed',
#   'RoW'),
#  ('planing, board, softwood, air dried',
#   'sawnwood, board, softwood, air dried, planed',
#   'CH'): ('planing, board, softwood, u=20%',
#   'sawnwood, board, softwood, dried (u=20%), planed',
#   'CH'),
#  ('planing, board, softwood, air dried',
#   'sawnwood, board, softwood, air dried, planed',
#   'RoW'): ('planing, board, softwood, u=20%',
#   'sawnwood, board, softwood, dried (u=20%), planed',
#   'RoW'),
#  ('planing, board, softwood, kiln dried',
#   'sawnwood, board, softwood, kiln dried, planed',
#   'CH'): ('planing, board, softwood, u=10%',
#   'sawnwood, board, softwood, dried (u=10%), planed',
#   'CH'),
#  ('planing, board, softwood, kiln dried',
#   'sawnwood, board, softwood, kiln dried, planed',
#   'RoW'): ('planing, board, softwood, u=10%',
#   'sawnwood, board, softwood, dried (u=10%), planed',
#   'RoW'),
#  ('rutile production, synthetic, 95% titanium dioxide',
#   'rutile, 95% titanium dioxide',
#   'GLO'): ('rutile production, synthetic, 95% titanium dioxide, Benelite process',
#   'rutile, 95% titanium dioxide',
#   'GLO'),
#  ('sawing, hardwood',
#   'sawnwood, hardwood, raw, debarked',
#   'CH'): ('sawing, hardwood', 'sawnwood, hardwood, raw', 'CH'),
#  ('sawing, hardwood',
#   'sawnwood, hardwood, raw, debarked',
#   'RoW'): ('sawing, hardwood', 'sawnwood, hardwood, raw', 'RoW'),
#  ('sawing, softwood',
#   'sawnwood, softwood, raw, debarked',
#   'CH'): ('sawing, softwood', 'sawnwood, softwood, raw', 'CH'),
#  ('sawing, softwood',
#   'sawnwood, softwood, raw, debarked',
#   'RoW'): ('sawing, softwood', 'sawnwood, softwood, raw', 'RoW'),
#  ('sawnwood production, hardwood, air dried, planed',
#   'sawnwood, hardwood, air dried, planed',
#   'RER'): ('sawnwood production, hardwood, dried (u=20%), planed',
#   'sawnwood, hardwood, dried (u=20%), planed',
#   'RER'),
#  ('sawnwood production, hardwood, air dried, planed',
#   'sawnwood, hardwood, air dried, planed',
#   'RoW'): ('sawnwood production, hardwood, dried (u=20%), planed',
#   'sawnwood, hardwood, dried (u=20%), planed',
#   'RoW'),
#  ('sawnwood production, hardwood, kiln dried, planed',
#   'sawnwood, hardwood, kiln dried, planed',
#   'RER'): ('sawnwood production, hardwood, dried (u=10%), planed',
#   'sawnwood, hardwood, dried (u=10%), planed',
#   'RER'),
#  ('sawnwood production, hardwood, kiln dried, planed',
#   'sawnwood, hardwood, kiln dried, planed',
#   'RoW'): ('sawnwood production, hardwood, dried (u=10%), planed',
#   'sawnwood, hardwood, dried (u=10%), planed',
#   'RoW'),
#  ('sawnwood production, hardwood, raw, air dried',
#   'sawnwood, hardwood, raw, air dried',
#   'RER'): ('sawnwood production, hardwood, raw, dried (u=20%)',
#   'sawnwood, hardwood, raw, dried (u=20%)',
#   'RER'),
#  ('sawnwood production, hardwood, raw, air dried',
#   'sawnwood, hardwood, raw, air dried',
#   'RoW'): ('sawnwood production, hardwood, raw, dried (u=20%)',
#   'sawnwood, hardwood, raw, dried (u=20%)',
#   'RoW'),
#  ('sawnwood production, hardwood, raw, kiln dried',
#   'sawnwood, hardwood, raw, kiln dried',
#   'RER'): ('sawnwood production, hardwood, raw, dried (u=10%)',
#   'sawnwood, hardwood, raw, dried (u=10%)',
#   'RER'),
#  ('sawnwood production, hardwood, raw, kiln dried',
#   'sawnwood, hardwood, raw, kiln dried',
#   'RoW'): ('sawnwood production, hardwood, raw, dried (u=10%)',
#   'sawnwood, hardwood, raw, dried (u=10%)',
#   'RoW'),
#  ('sawnwood production, softwood, air dried, planed',
#   'sawnwood, softwood, air dried, planed',
#   'RER'): ('sawnwood production, softwood, dried (u=20%), planed',
#   'sawnwood, softwood, dried (u=20%), planed',
#   'RER'),
#  ('sawnwood production, softwood, air dried, planed',
#   'sawnwood, softwood, air dried, planed',
#   'RoW'): ('sawnwood production, softwood, dried (u=20%), planed',
#   'sawnwood, softwood, dried (u=20%), planed',
#   'RoW'),
#  ('sawnwood production, softwood, kiln dried, planed',
#   'sawnwood, softwood, kiln dried, planed',
#   'RER'): ('sawnwood production, softwood, dried (u=10%), planed',
#   'sawnwood, softwood, dried (u=10%), planed',
#   'RER'),
#  ('sawnwood production, softwood, kiln dried, planed',
#   'sawnwood, softwood, kiln dried, planed',
#   'RoW'): ('sawnwood production, softwood, dried (u=10%), planed',
#   'sawnwood, softwood, dried (u=10%), planed',
#   'RoW'),
#  ('sawnwood production, softwood, raw, air dried',
#   'sawnwood, softwood, raw, air dried',
#   'RER'): ('sawnwood production, softwood, raw, dried (u=20%)',
#   'sawnwood, softwood, raw, dried (u=20%)',
#   'RER'),
#  ('sawnwood production, softwood, raw, air dried',
#   'sawnwood, softwood, raw, air dried',
#   'RoW'): ('sawnwood production, softwood, raw, dried (u=20%)',
#   'sawnwood, softwood, raw, dried (u=20%)',
#   'RoW'),
#  ('sawnwood production, softwood, raw, kiln dried',
#   'sawnwood, softwood, raw, kiln dried',
#   'RER'): ('sawnwood production, softwood, raw, dried (u=10%)',
#   'sawnwood, softwood, raw, dried (u=10%)',
#   'RER'),
#  ('sawnwood production, softwood, raw, kiln dried',
#   'sawnwood, softwood, raw, kiln dried',
#   'RoW'): ('sawnwood production, softwood, raw, dried (u=10%)',
#   'sawnwood, softwood, raw, dried (u=10%)',
#   'RoW'),
#  ('shaving, hardwood, measured as dry mass to generic market for residual wood, dry',
#   'residual wood, dry',
#   'GLO'): ('shavings, hardwood, measured as dry mass to generic market for residual wood, dry',
#   'residual wood, dry',
#   'GLO'),
#  ('shaving, softwood, measured as dry mass to generic market for residual wood, dry',
#   'residual wood, dry',
#   'GLO'): ('shavings, softwood, measured as dry mass to generic market for residual wood, dry',
#   'residual wood, dry',
#   'GLO'),
#  ('transport, freight, lorry >32 metric ton, EURO6',
#   'transport, freight, loryy >32 metric ton, EURO6',
#   'RER'): ('transport, freight, lorry >32 metric ton, EURO6',
#   'transport, freight, lorry >32 metric ton, EURO6',
#   'RER'),
#  ('transport, freight, lorry >32 metric ton, EURO6',
#   'transport, freight, loryy >32 metric ton, EURO6',
#   'RoW'): ('transport, freight, lorry >32 metric ton, EURO6',
#   'transport, freight, lorry >32 metric ton, EURO6',
#   'RoW')}

# %% [markdown]
# ## Export list of renamed activities, and missing activities
#
# Easiest to make this one big Excel sheet.

# %%
import xlsxwriter

# %%
workbook = xlsxwriter.Workbook('ecoinvent-31-33-migration.xlsx')
worksheet = workbook.add_worksheet('matching')

labels = [
    "Old name",
    "Old RP",
    "Old location",
    "New name",
    "New RP",
    "New location",
    "Comment",
]

for index, label in enumerate(labels):
    worksheet.write(0, index, label)

for index, row in enumerate(sorted(data_31.difference(data_33))):
    for col in (0, 1, 2):
        worksheet.write(index + 1, col, row[col])
    if row in renamed_31_33:
        new = renamed_31_33[row]
        for col in (0, 1, 2):
            worksheet.write(index + 1, col + 3, new[col])

workbook.close()

# %% [markdown]
# ## Export list of 3.3 activities for matching

# %%
workbook = xlsxwriter.Workbook('ecoinvent-33.xlsx')
worksheet = workbook.add_worksheet('data')

labels = [
    "Name",
    "RP",
    "Location",
]

for index, label in enumerate(labels):
    worksheet.write(0, index, label)

for index, row in enumerate(sorted(data_33)):
    for col in (0, 1, 2):
        worksheet.write(index + 1, col, row[col])

workbook.close()

# %% [markdown]
# # Now do the same thing for ecoinvent 3.2

# %%
overview = pd.read_excel("ecoinvent 3.2-3.3.xlsx", "overview")

# %%
data_32 = {(ds['name'], ds['reference product'], ds['location']) for ds in Database("3.2 cutoff")}

# %%
len(data_32), len(data_32.difference(data_33))
# Out:
# (12916, 319)

# %%
overview['status'].unique()
# Out:
# array(['new', 'present in both version without renaming',
#        'present in both version with renaming', 'deleted'], dtype=object)

# %%
overview
# Out:
#       ISIC number                                         ISIC class  \
# 0            2394            Manufacture of cement, lime and plaster
# 1            0161             Support activities for crop production
# 2              68                             Real estate activities
# 3            0127                          Growing of beverage crops
# 4            0810                  Quarrying of stone, sand and clay
# 5            3822          Treatment and disposal of hazardous waste
# 6            0127                          Growing of beverage crops
# 7            0161             Support activities for crop production
# 8            2394            Manufacture of cement, lime and plaster
# 9            0161             Support activities for crop production
# 10           3821      Treatment and disposal of non-hazardous waste
# 11           0127                          Growing of beverage crops
# 12           3830                                 Materials recovery
# 13           3510  Electric power generation, transmission and di...
# 14           3822          Treatment and disposal of hazardous waste
# 15           0161             Support activities for crop production
# 16           2220                   Manufacture of plastics products
# 17           2394            Manufacture of cement, lime and plaster
# 18           0125     Growing of other tree and bush fruits and nuts
# 19           3822          Treatment and disposal of hazardous waste
# 20           3700                                           Sewerage
# 21             68                             Real estate activities
# 22           2394            Manufacture of cement, lime and plaster
# 23           3821      Treatment and disposal of non-hazardous waste
# 24             68                             Real estate activities
# 25             68                             Real estate activities
# 26             68                             Real estate activities
# 27             68                             Real estate activities
# 28             68                             Real estate activities
# 29             68                             Real estate activities
# ...           ...                                                ...
# 12409        0220                                            Logging
# 12410        0220                                            Logging
# 12411        0220                                            Logging
# 12412        0220                                            Logging
# 12413        1311         Preparation and spinning of textile fibres
# 12414        1311         Preparation and spinning of textile fibres
# 12415        1311         Preparation and spinning of textile fibres
# 12416        1311         Preparation and spinning of textile fibres
# 12417        1050                      Manufacture of dairy products
# 12418        1050                      Manufacture of dairy products
# 12419        2023  Manufacture of soap and detergents, cleaning a...
# 12420        2023  Manufacture of soap and detergents, cleaning a...
# 12421        2023  Manufacture of soap and detergents, cleaning a...
# 12422        2023  Manufacture of soap and detergents, cleaning a...
# 12423        2592         Treatment and coating of metals; machining
# 12424        2592         Treatment and coating of metals; machining
# 12425        2592         Treatment and coating of metals; machining
# 12426        2592         Treatment and coating of metals; machining
# 12427        2592         Treatment and coating of metals; machining
# 12428        2592         Treatment and coating of metals; machining
# 12429        2011                     Manufacture of basic chemicals
# 12430        2011                     Manufacture of basic chemicals
# 12431        2011                     Manufacture of basic chemicals
# 12432        2011                     Manufacture of basic chemicals
# 12433        2011                     Manufacture of basic chemicals
# 12434        2011                     Manufacture of basic chemicals
# 12435        0729             Mining of other non-ferrous metal ores
# 12436        2011                     Manufacture of basic chemicals
# 12437        2011                     Manufacture of basic chemicals
# 12438        0113  Growing of vegetables and melons, roots and tu...
#
#                                         activityName 3.2 geography 3.2  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# 5                                                    NaN           NaN
# 6                                                    NaN           NaN
# 7                                                    NaN           NaN
# 8                                                    NaN           NaN
# 9                                                    NaN           NaN
# 10                                                   NaN           NaN
# 11                                                   NaN           NaN
# 12                                                   NaN           NaN
# 13                                                   NaN           NaN
# 14                                                   NaN           NaN
# 15                                                   NaN           NaN
# 16                                                   NaN           NaN
# 17                                                   NaN           NaN
# 18                                                   NaN           NaN
# 19                                                   NaN           NaN
# 20                                                   NaN           NaN
# 21                                                   NaN           NaN
# 22                                                   NaN           NaN
# 23                                                   NaN           NaN
# 24                                                   NaN           NaN
# 25                                                   NaN           NaN
# 26                                                   NaN           NaN
# 27                                                   NaN           NaN
# 28                                                   NaN           NaN
# 29                                                   NaN           NaN
# ...                                                  ...           ...
# 12409            yarding, mobile cable yarder on trailer           GLO
# 12410            yarding, mobile cable yarder on trailer           RER
# 12411                               yarding, sled yarder           GLO
# 12412                               yarding, sled yarder           RER
# 12413                              yarn production, jute           GLO
# 12414                              yarn production, jute            IN
# 12415                             yarn production, kenaf           GLO
# 12416                             yarn production, kenaf            IN
# 12417                   yogurt production, from cow milk         CA-QC
# 12418                   yogurt production, from cow milk           GLO
# 12419                         zeolite production, powder           GLO
# 12420                         zeolite production, powder           RER
# 12421  zeolite production, slurry, without water, in ...           GLO
# 12422  zeolite production, slurry, without water, in ...           RER
# 12423                                zinc coating, coils           GLO
# 12424                                zinc coating, coils           RER
# 12425                               zinc coating, pieces           GLO
# 12426                               zinc coating, pieces           RER
# 12427       zinc coating, pieces, adjustment per micro-m           GLO
# 12428       zinc coating, pieces, adjustment per micro-m           RER
# 12429                        zinc monosulfate production           GLO
# 12430                        zinc monosulfate production           RER
# 12431                              zinc oxide production           GLO
# 12432                              zinc oxide production           RER
# 12433                            zinc sulfide production           GLO
# 12434                            zinc sulfide production           RER
# 12435                           zinc-lead mine operation           GLO
# 12436                         zirconium oxide production            AU
# 12437                         zirconium oxide production           GLO
# 12438                                zucchini production           GLO
#
#                                         activityName 3.3  \
# 0      cement, pozzolana and fly ash 36-55%,non-US to...
# 1       market for petrol, unleaded, burned in machinery
# 2                        land use change, perennial crop
# 3                  coffee green bean production, robusta
# 4                             market for gravel, crushed
# 5                 market for fly ash and scrubber sludge
# 6                                  tea production, dried
# 7             nutrient supply from manure, solid, cattle
# 8      cement, alternative constituents 6-20% to gene...
# 9                        market for establishing orchard
# 10     treatment of waste polystyrene, sanitary landfill
# 11                 coffee green bean production, arabica
# 12         treatment of waste glass sheet, sorting plant
# 13     electricity, high voltage, hydro, import from ...
# 14     treatment of waste emulsion paint, hazardous w...
# 15     treatment, sludge from pulp and paper producti...
# 16                       horticultural fleece production
# 17     cement, alternative constituents 21-35% to gen...
# 18         strawberry production, in unheated greenhouse
# 19                      market for spent solvent mixture
# 20     treatment of wastewater, average, capacity 1E9...
# 21     land already in use, perennial cropland to ann...
# 22     cement, alternative constituents 21-35% to gen...
# 23                     market for wood ash mixture, pure
# 24               market for land use change, annual crop
# 25     clear-cutting, secondary forest to arable land...
# 26                       land use change, perennial crop
# 27               market for land use change, annual crop
# 28     market for land tenure, arable land, measured ...
# 29     land already in use, perennial cropland to ann...
# ...                                                  ...
# 12409            yarding, mobile cable yarder on trailer
# 12410            yarding, mobile cable yarder on trailer
# 12411                               yarding, sled yarder
# 12412                               yarding, sled yarder
# 12413                              yarn production, jute
# 12414                              yarn production, jute
# 12415                             yarn production, kenaf
# 12416                             yarn production, kenaf
# 12417                   yogurt production, from cow milk
# 12418                   yogurt production, from cow milk
# 12419                         zeolite production, powder
# 12420                         zeolite production, powder
# 12421  zeolite production, slurry, without water, in ...
# 12422  zeolite production, slurry, without water, in ...
# 12423                                zinc coating, coils
# 12424                                zinc coating, coils
# 12425                               zinc coating, pieces
# 12426                               zinc coating, pieces
# 12427       zinc coating, pieces, adjustment per micro-m
# 12428       zinc coating, pieces, adjustment per micro-m
# 12429                        zinc monosulfate production
# 12430                        zinc monosulfate production
# 12431                              zinc oxide production
# 12432                              zinc oxide production
# 12433                            zinc sulfide production
# 12434                            zinc sulfide production
# 12435                           zinc-lead mine operation
# 12436                         zirconium oxide production
# 12437                         zirconium oxide production
# 12438                                zucchini production
#
#                     geography 3.3  \
# 0                              CH
# 1                             GLO
# 2                              US
# 3                              IN
# 4                              CH
# 5      Europe without Switzerland
# 6                              CN
# 7                             GLO
# 8      Europe without Switzerland
# 9                             GLO
# 10     Europe without Switzerland
# 11                             CO
# 12     Europe without Switzerland
# 13                            GLO
# 14     Europe without Switzerland
# 15     Europe without Switzerland
# 16                             CH
# 17     Europe without Switzerland
# 18                            GLO
# 19                             CH
# 20     Europe without Switzerland
# 21                             CA
# 22                             CH
# 23     Europe without Switzerland
# 24                             IN
# 25                             HN
# 26                             FR
# 27                             IT
# 28                             NL
# 29                             US
# ...                           ...
# 12409                         GLO
# 12410                         RER
# 12411                         GLO
# 12412                         RER
# 12413                         GLO
# 12414                          IN
# 12415                         GLO
# 12416                          IN
# 12417                       CA-QC
# 12418                         GLO
# 12419                         GLO
# 12420                         RER
# 12421                         GLO
# 12422                         RER
# 12423                         GLO
# 12424                         RER
# 12425                         GLO
# 12426                         RER
# 12427                         GLO
# 12428                         RER
# 12429                         GLO
# 12430                         RER
# 12431                         GLO
# 12432                         RER
# 12433                         GLO
# 12434                         RER
# 12435                         GLO
# 12436                          AU
# 12437                         GLO
# 12438                         GLO
#
#                                              Product 3.2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 12409                                      cable yarding
# 12410                                      cable yarding
# 12411                                      cable yarding
# 12412                                      cable yarding
# 12413                                         yarn, jute
# 12414                                         yarn, jute
# 12415                                        yarn, kenaf
# 12416                                        yarn, kenaf
# 12417                              yogurt, from cow milk
# 12418                              yogurt, from cow milk
# 12419                                    zeolite, powder
# 12420                                    zeolite, powder
# 12421  zeolite, slurry, without water, in 50% solutio...
# 12422  zeolite, slurry, without water, in 50% solutio...
# 12423                                   zinc coat, coils
# 12424                                   zinc coat, coils
# 12425                                  zinc coat, pieces
# 12426                                  zinc coat, pieces
# 12427          zinc coat, pieces, adjustment per micro-m
# 12428          zinc coat, pieces, adjustment per micro-m
# 12429                                   zinc monosulfate
# 12430                                   zinc monosulfate
# 12431                                         zinc oxide
# 12432                                         zinc oxide
# 12433                                       zinc sulfide
# 12434                                       zinc sulfide
# 12435                                   zinc concentrate
# 12436                                    zirconium oxide
# 12437                                    zirconium oxide
# 12438                                           zucchini
#
#                                              Product 3.3 Product Unit 3.2  \
# 0                                    cement, unspecified              NaN
# 1                  petrol, unleaded, burned in machinery              NaN
# 2                        land use change, perennial crop              NaN
# 3                                     coffee, green bean              NaN
# 4                                        gravel, crushed              NaN
# 5                            fly ash and scrubber sludge              NaN
# 6                                             tea, dried              NaN
# 7                              nitrogen fertiliser, as N              NaN
# 8                                    cement, unspecified              NaN
# 9                                   establishing orchard              NaN
# 10                                     waste polystyrene              NaN
# 11                                    coffee, green bean              NaN
# 12                                     waste glass sheet              NaN
# 13                             electricity, high voltage              NaN
# 14                                  waste emulsion paint              NaN
# 15                 sludge from pulp and paper production              NaN
# 16                                  horticultural fleece              NaN
# 17                                   cement, unspecified              NaN
# 18                                            strawberry              NaN
# 19                                 spent solvent mixture              NaN
# 20                                   wastewater, average              NaN
# 21     land tenure, arable land, measured as carbon n...              NaN
# 22                                   cement, unspecified              NaN
# 23                                wood ash mixture, pure              NaN
# 24                          land use change, annual crop              NaN
# 25     land tenure, arable land, measured as carbon n...              NaN
# 26                       land use change, perennial crop              NaN
# 27                          land use change, annual crop              NaN
# 28     land tenure, arable land, measured as carbon n...              NaN
# 29     land tenure, arable land, measured as carbon n...              NaN
# ...                                                  ...              ...
# 12409                                      cable yarding             hour
# 12410                                      cable yarding             hour
# 12411                                      cable yarding             hour
# 12412                                      cable yarding             hour
# 12413                                         yarn, jute               kg
# 12414                                         yarn, jute               kg
# 12415                                        yarn, kenaf               kg
# 12416                                        yarn, kenaf               kg
# 12417                              yogurt, from cow milk               kg
# 12418                              yogurt, from cow milk               kg
# 12419                                    zeolite, powder               kg
# 12420                                    zeolite, powder               kg
# 12421  zeolite, slurry, without water, in 50% solutio...               kg
# 12422  zeolite, slurry, without water, in 50% solutio...               kg
# 12423                                   zinc coat, coils               m2
# 12424                                   zinc coat, coils               m2
# 12425                                  zinc coat, pieces               m2
# 12426                                  zinc coat, pieces               m2
# 12427          zinc coat, pieces, adjustment per micro-m               m2
# 12428          zinc coat, pieces, adjustment per micro-m               m2
# 12429                                   zinc monosulfate               kg
# 12430                                   zinc monosulfate               kg
# 12431                                         zinc oxide               kg
# 12432                                         zinc oxide               kg
# 12433                                       zinc sulfide               kg
# 12434                                       zinc sulfide               kg
# 12435                                   zinc concentrate               kg
# 12436                                    zirconium oxide               kg
# 12437                                    zirconium oxide               kg
# 12438                                           zucchini               kg
#
#       Product Unit 3.3            ...                      Tags 3.3  \
# 0                   kg            ...                           NaN
# 1                   MJ            ...                           NaN
# 2                   ha            ...                         WFLDB
# 3                   kg            ...                         WFLDB
# 4                   kg            ...                           NaN
# 5                   kg            ...                           NaN
# 6                   kg            ...                         WFLDB
# 7                   kg            ...                           NaN
# 8                   kg            ...                           NaN
# 9                 unit            ...                           NaN
# 10                  kg            ...                     Treatment
# 11                  kg            ...                         WFLDB
# 12                  kg            ...                     Treatment
# 13                 kWh            ...                        Canada
# 14                  kg            ...                     Treatment
# 15                  kg            ...                           NaN
# 16                  m2            ...                         WFLDB
# 17                  kg            ...                           NaN
# 18                  kg            ...                         WFLDB
# 19                  kg            ...                           NaN
# 20                  m3            ...                     Treatment
# 21                  kg            ...                         WFLDB
# 22                  kg            ...                           NaN
# 23                  kg            ...                           NaN
# 24                  ha            ...                           NaN
# 25                  kg            ...                         WFLDB
# 26                  ha            ...                         WFLDB
# 27                  ha            ...                           NaN
# 28                  kg            ...                           NaN
# 29                  kg            ...                         WFLDB
# ...                ...            ...                           ...
# 12409             hour            ...                           NaN
# 12410             hour            ...                           NaN
# 12411             hour            ...                           NaN
# 12412             hour            ...                           NaN
# 12413               kg            ...              ConvertedDataset
# 12414               kg            ...              ConvertedDataset
# 12415               kg            ...              ConvertedDataset
# 12416               kg            ...              ConvertedDataset
# 12417               kg            ...                           NaN
# 12418               kg            ...                           NaN
# 12419               kg            ...              ConvertedDataset
# 12420               kg            ...              ConvertedDataset
# 12421               kg            ...              ConvertedDataset
# 12422               kg            ...              ConvertedDataset
# 12423               m2            ...              ConvertedDataset
# 12424               m2            ...              ConvertedDataset
# 12425               m2            ...              ConvertedDataset
# 12426               m2            ...              ConvertedDataset
# 12427               m2            ...              ConvertedDataset
# 12428               m2            ...              ConvertedDataset
# 12429               kg            ...              ConvertedDataset
# 12430               kg            ...              ConvertedDataset
# 12431               kg            ...              ConvertedDataset
# 12432               kg            ...              ConvertedDataset
# 12433               kg            ...              ConvertedDataset
# 12434               kg            ...              ConvertedDataset
# 12435               kg            ...              ConvertedDataset
# 12436               kg            ...              ConvertedDataset
# 12437               kg            ...              ConvertedDataset
# 12438               kg            ...                           NaN
#
#         Start 3.2     End 3.2   Start 3.3     End 3.3 Time period 3.2  \
# 0             NaN         NaN  2013-01-01  2013-12-31             NaN
# 1             NaN         NaN  2009-01-01  2012-12-31             NaN
# 2             NaN         NaN  2010-01-01  2015-12-31             NaN
# 3             NaN         NaN  2012-01-01  2014-12-31             NaN
# 4             NaN         NaN  2011-01-01  2011-12-31             NaN
# 5             NaN         NaN  2011-01-01  2011-12-31             NaN
# 6             NaN         NaN  2009-01-01  2012-12-31             NaN
# 7             NaN         NaN  2009-01-01  2016-12-31             NaN
# 8             NaN         NaN  2013-01-01  2013-12-31             NaN
# 9             NaN         NaN  2011-01-01  2011-12-31             NaN
# 10            NaN         NaN  1994-01-01  2000-12-31             NaN
# 11            NaN         NaN  2012-01-01  2014-12-31             NaN
# 12            NaN         NaN  1994-01-01  2002-12-31             NaN
# 13            NaN         NaN  2014-01-01  2014-12-31             NaN
# 14            NaN         NaN  1997-01-01  2000-12-31             NaN
# 15            NaN         NaN  2011-01-01  2012-12-31             NaN
# 16            NaN         NaN  2009-01-01  2012-12-31             NaN
# 17            NaN         NaN  2013-01-01  2013-12-31             NaN
# 18            NaN         NaN  2009-01-01  2012-12-31             NaN
# 19            NaN         NaN  2011-01-01  2011-12-31             NaN
# 20            NaN         NaN  1994-01-01  2000-12-31             NaN
# 21            NaN         NaN  2010-01-01  2015-12-31             NaN
# 22            NaN         NaN  2013-01-01  2013-12-31             NaN
# 23            NaN         NaN  2011-01-01  2011-12-31             NaN
# 24            NaN         NaN  2010-01-01  2015-12-31             NaN
# 25            NaN         NaN  2010-01-01  2015-12-31             NaN
# 26            NaN         NaN  2010-01-01  2015-12-31             NaN
# 27            NaN         NaN  2010-01-01  2015-12-31             NaN
# 28            NaN         NaN  2010-01-01  2015-12-31             NaN
# 29            NaN         NaN  2010-01-01  2015-12-31             NaN
# ...           ...         ...         ...         ...             ...
# 12409  2012-01-01  2012-12-31  2012-01-01  2012-12-31     2012 - 2012
# 12410  2012-01-01  2012-12-31  2012-01-01  2012-12-31     2012 - 2012
# 12411  2012-01-01  2012-12-31  2012-01-01  2012-12-31     2012 - 2012
# 12412  2012-01-01  2012-12-31  2012-01-01  2012-12-31     2012 - 2012
# 12413  2003-01-01  2007-12-31  2003-01-01  2007-12-31     2003 - 2007
# 12414  2003-01-01  2007-12-31  2003-01-01  2007-12-31     2003 - 2007
# 12415  2003-01-01  2007-12-31  2003-01-01  2007-12-31     2003 - 2007
# 12416  2003-01-01  2007-12-31  2003-01-01  2007-12-31     2003 - 2007
# 12417  2010-01-01  2012-12-31  2010-01-01  2012-12-31     2010 - 2012
# 12418  2010-01-01  2012-12-31  2010-01-01  2012-12-31     2010 - 2012
# 12419  1990-01-01  1995-12-31  1990-01-01  1995-12-31     1990 - 1995
# 12420  1990-01-01  1995-12-31  1990-01-01  1995-12-31     1990 - 1995
# 12421  1990-01-01  1995-12-31  1990-01-01  1995-12-31     1990 - 1995
# 12422  1990-01-01  1995-12-31  1990-01-01  1995-12-31     1990 - 1995
# 12423  1996-01-01  2002-12-31  1996-01-01  2002-12-31     1996 - 2002
# 12424  1996-01-01  2002-12-31  1996-01-01  2002-12-31     1996 - 2002
# 12425  1996-01-01  2002-12-31  1996-01-01  2002-12-31     1996 - 2002
# 12426  1996-01-01  2002-12-31  1996-01-01  2002-12-31     1996 - 2002
# 12427  1996-01-01  2002-12-31  1996-01-01  2002-12-31     1996 - 2002
# 12428  1996-01-01  2002-12-31  1996-01-01  2002-12-31     1996 - 2002
# 12429  2005-01-01  2007-12-31  2005-01-01  2007-12-31     2005 - 2007
# 12430  2005-01-01  2007-12-31  2005-01-01  2007-12-31     2005 - 2007
# 12431  2005-01-01  2007-12-31  2005-01-01  2007-12-31     2005 - 2007
# 12432  2005-01-01  2007-12-31  2005-01-01  2007-12-31     2005 - 2007
# 12433  2005-01-01  2007-12-31  2005-01-01  2007-12-31     2005 - 2007
# 12434  2005-01-01  2007-12-31  2005-01-01  2007-12-31     2005 - 2007
# 12435  1994-01-01  2003-12-31  1994-01-01  2003-12-31     1994 - 2003
# 12436  2000-01-01  2005-12-31  2000-01-01  2005-12-31     2000 - 2005
# 12437  2000-01-01  2005-12-31  2000-01-01  2005-12-31     2000 - 2005
# 12438  2010-01-01  2010-12-31  2010-01-01  2010-12-31     2010 - 2010
#
#       Time period 3.3 Technology Level 3.2 Technology Level 3.3  \
# 0         2013 - 2013                  NaN              Current
# 1         2009 - 2012                  NaN            Undefined
# 2         2010 - 2015                  NaN              Current
# 3         2012 - 2014                  NaN              Current
# 4         2011 - 2011                  NaN            Undefined
# 5         2011 - 2011                  NaN            Undefined
# 6         2009 - 2012                  NaN              Current
# 7         2009 - 2016                  NaN              Current
# 8         2013 - 2013                  NaN              Current
# 9         2011 - 2011                  NaN            Undefined
# 10        1994 - 2000                  NaN              Current
# 11        2012 - 2014                  NaN              Current
# 12        1994 - 2002                  NaN              Current
# 13        2014 - 2014                  NaN              Current
# 14        1997 - 2000                  NaN              Current
# 15        2011 - 2012                  NaN              Current
# 16        2009 - 2012                  NaN              Current
# 17        2013 - 2013                  NaN              Current
# 18        2009 - 2012                  NaN              Current
# 19        2011 - 2011                  NaN            Undefined
# 20        1994 - 2000                  NaN              Current
# 21        2010 - 2015                  NaN              Current
# 22        2013 - 2013                  NaN              Current
# 23        2011 - 2011                  NaN            Undefined
# 24        2010 - 2015                  NaN            Undefined
# 25        2010 - 2015                  NaN              Current
# 26        2010 - 2015                  NaN              Current
# 27        2010 - 2015                  NaN            Undefined
# 28        2010 - 2015                  NaN            Undefined
# 29        2010 - 2015                  NaN              Current
# ...               ...                  ...                  ...
# 12409     2012 - 2012              Current              Current
# 12410     2012 - 2012              Current              Current
# 12411     2012 - 2012              Current              Current
# 12412     2012 - 2012              Current              Current
# 12413     2003 - 2007              Current              Current
# 12414     2003 - 2007              Current              Current
# 12415     2003 - 2007              Current              Current
# 12416     2003 - 2007              Current              Current
# 12417     2010 - 2012              Current              Current
# 12418     2010 - 2012              Current              Current
# 12419     1990 - 1995              Current              Current
# 12420     1990 - 1995              Current              Current
# 12421     1990 - 1995              Current              Current
# 12422     1990 - 1995              Current              Current
# 12423     1996 - 2002              Current              Current
# 12424     1996 - 2002              Current              Current
# 12425     1996 - 2002              Current              Current
# 12426     1996 - 2002              Current              Current
# 12427     1996 - 2002              Current              Current
# 12428     1996 - 2002              Current              Current
# 12429     2005 - 2007              Current              Current
# 12430     2005 - 2007              Current              Current
# 12431     2005 - 2007              Current              Current
# 12432     2005 - 2007              Current              Current
# 12433     2005 - 2007              Current              Current
# 12434     2005 - 2007              Current              Current
# 12435     1994 - 2003              Current              Current
# 12436     2000 - 2005              Current              Current
# 12437     2000 - 2005              Current              Current
# 12438     2010 - 2010              Current              Current
#
#       change in Technology Level
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 12409                         no
# 12410                         no
# 12411                         no
# 12412                         no
# 12413                         no
# 12414                         no
# 12415                         no
# 12416                         no
# 12417                         no
# 12418                         no
# 12419                         no
# 12420                         no
# 12421                         no
# 12422                         no
# 12423                         no
# 12424                         no
# 12425                         no
# 12426                         no
# 12427                         no
# 12428                         no
# 12429                         no
# 12430                         no
# 12431                         no
# 12432                         no
# 12433                         no
# 12434                         no
# 12435                         no
# 12436                         no
# 12437                         no
# 12438                         no
#
# [12439 rows x 24 columns]

# %%
renamed_mask = overview['status'] == 'present in both version with renaming'
renamed_mask.sum()
# Out:
# 81

# %%
renamed_32_33 = {}

for _, row in overview[renamed_mask].iterrows():
    value = (row['activityName 3.3'], row['Product 3.3'], row['geography 3.3'])
    key = (row['activityName 3.2'], row['Product 3.2'], row['geography 3.2'])
    
    if key not in data_32 and key[2] == 'GLO':
        key = (key[0], key[1], 'RoW')
    if value not in data_33 and value[2] == 'GLO':
        value = (value[0], value[1], 'RoW')
    
    if key in data_32 and value in data_33:
        renamed_32_33[key] = value

# %%
renamed_32_33
# Out:
# {('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area 1'): ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, Africa'),
#  ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area 2, without Quebec'): ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, North America, without Quebec'),
#  ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area 3'): ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, South America'),
#  ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area 4&5 without China'): ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, Asia, without China and GCC'),
#  ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area 8'): ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, Gulf Cooperation Council'),
#  ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, Europe outside EU & EFTA'): ('aluminium production, primary, ingot',
#   'aluminium, primary, ingot',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area 1'): ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, Africa'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area 2, without Quebec'): ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, North America, without Quebec'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area 3'): ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, South America'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area 4&5 without China'): ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, Asia, without China and GCC'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area 8'): ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, Gulf Cooperation Council'),
#  ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, Europe outside EU & EFTA'): ('aluminium production, primary, liquid, prebake',
#   'aluminium, primary, liquid',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('coconut production, husked',
#   'coconut, husked',
#   'PH'): ('coconut production, dehusked', 'coconut, dehusked', 'PH'),
#  ('coconut production, husked',
#   'coconut, husked',
#   'RoW'): ('coconut production, dehusked', 'coconut, dehusked', 'RoW'),
#  ('diesel-electric generating set production 10MW production',
#   'diesel-electric generating set, 10MW',
#   'RER'): ('diesel-electric generating set production, 10MW',
#   'diesel-electric generating set, 10MW',
#   'RER'),
#  ('diesel-electric generating set production 10MW production',
#   'diesel-electric generating set, 10MW',
#   'RoW'): ('diesel-electric generating set production, 10MW',
#   'diesel-electric generating set, 10MW',
#   'RoW'),
#  ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 1'): ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Africa'),
#  ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 4&5 without China'): ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Asia, without China and GCC'),
#  ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Europe outside EU & EFTA'): ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 1'): ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Africa'),
#  ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 3'): ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, South America'),
#  ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 4&5 without China'): ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Asia, without China and GCC'),
#  ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Europe outside EU & EFTA'): ('electricity production, hydro, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 3'): ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, South America'),
#  ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 8'): ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Gulf Cooperation Council'),
#  ('electricity production, nuclear, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('electricity production, nuclear, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('electricity production, oil, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 8'): ('electricity production, oil, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Gulf Cooperation Council'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 1'): ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Africa'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 3'): ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, South America'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 4&5 without China'): ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Asia, without China and GCC'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 8'): ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Gulf Cooperation Council'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Europe outside EU & EFTA'): ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('ethanol production from sugar cane',
#   'ethanol, without water, in 95% solution state, from fermentation',
#   'BR'): ('ethanol production from sugarcane',
#   'ethanol, without water, in 95% solution state, from fermentation',
#   'BR'),
#  ('harvesting, by complete harvester, potatoes',
#   'harvesting, by complete harvester, potatoes',
#   'CA-QC'): ('harvesting, by complete harvester, ground crops',
#   'harvesting, by complete harvester, ground crops',
#   'CA-QC'),
#  ('harvesting, by complete harvester, potatoes',
#   'harvesting, by complete harvester, potatoes',
#   'CH'): ('harvesting, by complete harvester, ground crops',
#   'harvesting, by complete harvester, ground crops',
#   'CH'),
#  ('harvesting, by complete harvester, potatoes',
#   'harvesting, by complete harvester, potatoes',
#   'RoW'): ('harvesting, by complete harvester, ground crops',
#   'harvesting, by complete harvester, ground crops',
#   'RoW'),
#  ('market for ash, from combustion of bagasse from sugar cane',
#   'ash, from combustion of bagasse from sugar cane',
#   'GLO'): ('market for ash, from combustion of bagasse from sugarcane',
#   'ash, from combustion of bagasse from sugarcane',
#   'GLO'),
#  ('market for coconut, husked',
#   'coconut, husked',
#   'GLO'): ('market for coconut, dehusked', 'coconut, dehusked', 'GLO'),
#  ('market for diesel-electric generating set production 10MW',
#   'diesel-electric generating set, 10MW',
#   'GLO'): ('market for diesel-electric generating set, 10MW',
#   'diesel-electric generating set, 10MW',
#   'GLO'),
#  ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 1'): ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Africa'),
#  ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 3'): ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, South America'),
#  ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 4&5 without China'): ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Asia, without China and GCC'),
#  ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area 8'): ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Gulf Cooperation Council'),
#  ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Europe outside EU & EFTA'): ('market for electricity, high voltage, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 1'): ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Africa'),
#  ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 2, without Quebec'): ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, North America, without Quebec'),
#  ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 3'): ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, South America'),
#  ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 4&5 without China'): ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Asia, without China and GCC'),
#  ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area 8'): ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Gulf Cooperation Council'),
#  ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Europe outside EU & EFTA'): ('market for electricity, medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  ('market for harvesting, by complete harvester, potatoes',
#   'harvesting, by complete harvester, potatoes',
#   'GLO'): ('market for harvesting, by complete harvester, ground crops',
#   'harvesting, by complete harvester, ground crops',
#   'GLO'),
#  ('market for rock wool', 'rock wool', 'GLO'): ('market for stone wool',
#   'stone wool',
#   'GLO'),
#  ('market for rock wool factory',
#   'rock wool factory',
#   'GLO'): ('market for stone wool factory', 'stone wool factory', 'GLO'),
#  ('market for rock wool, packed',
#   'rock wool, packed',
#   'GLO'): ('market for stone wool, packed', 'stone wool, packed', 'GLO'),
#  ('onion855 production', 'onion', 'GLO'): ('onion production', 'onion', 'RoW'),
#  ('rock wool factory construction',
#   'rock wool factory',
#   'CH'): ('stone wool factory construction', 'stone wool factory', 'CH'),
#  ('rock wool factory construction',
#   'rock wool factory',
#   'RoW'): ('stone wool factory construction', 'stone wool factory', 'RoW'),
#  ('rock wool production', 'rock wool', 'CH'): ('stone wool production',
#   'stone wool',
#   'CH'),
#  ('rock wool production', 'rock wool', 'RoW'): ('stone wool production',
#   'stone wool',
#   'RoW'),
#  ('rock wool production, packed',
#   'rock wool, packed',
#   'CH'): ('stone wool production, packed', 'stone wool, packed', 'CH'),
#  ('rock wool production, packed',
#   'rock wool, packed',
#   'RoW'): ('stone wool production, packed', 'stone wool, packed', 'RoW'),
#  ('treatment of biogas, burned in micro gas turbine 100kWe',
#   'electricity, low voltage',
#   'CH'): ('biogas, burned in micro gas turbine 100kWe',
#   'electricity, low voltage',
#   'CH'),
#  ('treatment of biogas, burned in polymer electrolyte membrane fuel cell 2kWe, future',
#   'electricity, low voltage',
#   'CH'): ('biogas, burned in polymer electrolyte membrane fuel cell 2kWe, future',
#   'electricity, low voltage',
#   'CH'),
#  ('treatment of biogas, burned in solid oxide fuel cell 125kWe, future',
#   'electricity, low voltage',
#   'CH'): ('biogas, burned in solid oxide fuel cell 125kWe, future',
#   'electricity, low voltage',
#   'CH'),
#  ('treatment of biogas, burned in solid oxide fuel cell, with micro gas turbine, 180kWe, future',
#   'electricity, low voltage',
#   'CH'): ('biogas, burned in solid oxide fuel cell, with micro gas turbine, 180kWe, future',
#   'electricity, low voltage',
#   'CH')}

# %%
workbook = xlsxwriter.Workbook('ecoinvent-32-33-migration.xlsx')
worksheet = workbook.add_worksheet('matching')

labels = [
    "Old name",
    "Old RP",
    "Old location",
    "New name",
    "New RP",
    "New location",
    "Comment",
]

for index, label in enumerate(labels):
    worksheet.write(0, index, label)

for index, row in enumerate(sorted(data_32.difference(data_33))):
    for col in (0, 1, 2):
        worksheet.write(index + 1, col, row[col])
    if row in renamed_32_33:
        new = renamed_32_33[row]
        for col in (0, 1, 2):
            worksheet.write(index + 1, col + 3, new[col])

workbook.close()

# %% [markdown]
# # Validate manual lists
#
# Need to make sure we can find each new linked activity.

# %%
import xlrd

# %%
ws = xlrd.open_workbook("/Users/cmutel/Downloads/ecoinvent-32-33-migration.xlsx").sheet_by_name("matching")
new_data = [
    tuple([ws.cell_value(row, col) for col in (3,4,5)]) 
    for row in range(1, ws.nrows) 
    if ws.cell_value(row, 3)
]

for key in new_data:
    if key not in data_33:
        print(key)

# %%
ws = xlrd.open_workbook("/Users/cmutel/Downloads/ecoinvent-31-33-migration.xlsx").sheet_by_name("matching")
new_data = [
    tuple([ws.cell_value(row, col) for col in (3,4,5)]) 
    for row in range(1, ws.nrows) 
    if ws.cell_value(row, 3)
]

for key in new_data:
    if key not in data_33:
        print(key)

# %% [markdown]
# How many of our 517 missing activities were `deleted or replaced`?

# %%
changed_31 = set(zip(overview['activityName'], overview['reference product'], overview['geography']))
517 - len(data_31.difference(data_32).difference(changed_31))
# Out:
# 275

# %% [markdown]
# ### Changed reference products
#
# Find cases where the reference or byproduct name was changed. Byproducts need to be included because this list if for the undefined datasets - the byproducts can become reference product in new activities, depending on the system model.

# %%
changes = pd.read_excel(fp, "quantitative changes")

# %% [markdown]
# There are four types of changes listed here:

# %%
changes['change'].unique()
# Out:
# array(['updated', 'renaming only', 'added', 'deleted'], dtype=object)

# %% [markdown]
# We don't care about `added` activities, nor do we care about `updated` activities. Updated activities have changes in the amount, production volume, or price of an exchange, but we are trying to figure out how to update links from 3.1 to 3.2 - not update 3.1 itself. So we don't need to care about these changes.

# %% [markdown]
# Find changes where:
#
# * The change was to a reference or byproduct
# * The change was a renaming change

# %%
mask = (
    ((changes['group'] == 'ReferenceProduct') | (changes['group'] == 'Byproduct')) *
    (changes['change'] == 'renaming only')
)
mask.sum()
# Out:
# Warning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
# 183

# %%
changes[mask]
# Out:
#       ISIC number                                       ISIC class  \
# 480          1610                   Sawmilling and planing of wood
# 481          1610                   Sawmilling and planing of wood
# 483          1610                   Sawmilling and planing of wood
# 633          1610                   Sawmilling and planing of wood
# 1914         1610                   Sawmilling and planing of wood
# 3111         1610                   Sawmilling and planing of wood
# 3113         1610                   Sawmilling and planing of wood
# 3115         1610                   Sawmilling and planing of wood
# 3154         1610                   Sawmilling and planing of wood
# 3155         1610                   Sawmilling and planing of wood
# 3210         1610                   Sawmilling and planing of wood
# 3240         1610                   Sawmilling and planing of wood
# 4041         1610                   Sawmilling and planing of wood
# 4282         1610                   Sawmilling and planing of wood
# 4293         1610                   Sawmilling and planing of wood
# 4815         4923                        Freight transport by road
# 4898         1610                   Sawmilling and planing of wood
# 4899         1610                   Sawmilling and planing of wood
# 4900         1610                   Sawmilling and planing of wood
# 5115         1610                   Sawmilling and planing of wood
# 5116         1610                   Sawmilling and planing of wood
# 5117         1610                   Sawmilling and planing of wood
# 5662         1610                   Sawmilling and planing of wood
# 5711         1610                   Sawmilling and planing of wood
# 5713         1610                   Sawmilling and planing of wood
# 5714         1610                   Sawmilling and planing of wood
# 6127         1610                   Sawmilling and planing of wood
# 6192         2392           Manufacture of clay building materials
# 6193         2392           Manufacture of clay building materials
# 6625         1610                   Sawmilling and planing of wood
# ...           ...                                              ...
# 31470        1610                   Sawmilling and planing of wood
# 31516        1610                   Sawmilling and planing of wood
# 31520        1610                   Sawmilling and planing of wood
# 31707        1610                   Sawmilling and planing of wood
# 31713        1610                   Sawmilling and planing of wood
# 32427        1610                   Sawmilling and planing of wood
# 32431        1610                   Sawmilling and planing of wood
# 32901        1610                   Sawmilling and planing of wood
# 32902        1610                   Sawmilling and planing of wood
# 32991        1610                   Sawmilling and planing of wood
# 33050        1610                   Sawmilling and planing of wood
# 33402        1610                   Sawmilling and planing of wood
# 33552        1610                   Sawmilling and planing of wood
# 33590        1610                   Sawmilling and planing of wood
# 33591        1610                   Sawmilling and planing of wood
# 33592        1610                   Sawmilling and planing of wood
# 33932        1610                   Sawmilling and planing of wood
# 34006        4923                        Freight transport by road
# 34367        1610                   Sawmilling and planing of wood
# 34380        1610                   Sawmilling and planing of wood
# 34893        1610                   Sawmilling and planing of wood
# 35269        1610                   Sawmilling and planing of wood
# 35270        1610                   Sawmilling and planing of wood
# 35484        1610                   Sawmilling and planing of wood
# 35598        2392           Manufacture of clay building materials
# 35599        2392           Manufacture of clay building materials
# 35600        2392           Manufacture of clay building materials
# 36473       3510a  Electric power generation based on liquid fuels
# 36474       3510a  Electric power generation based on liquid fuels
# 36475       3510a  Electric power generation based on liquid fuels
#
#                                             activityName geography  \
# 480    sawnwood production, softwood, dried (u=10%), ...       RER
# 481    sawnwood production, softwood, dried (u=10%), ...       RER
# 483    sawnwood production, softwood, dried (u=10%), ...       RER
# 633            lath, softwood, raw, kiln drying to u=10%        CH
# 1914                     planing, board, softwood, u=10%        CH
# 3111   sawnwood production, hardwood, dried (u=10%), ...       GLO
# 3113   sawnwood production, hardwood, dried (u=10%), ...       GLO
# 3115   sawnwood production, hardwood, dried (u=10%), ...       GLO
# 3154   market for shavings, hardwood, measured as dry...       GLO
# 3155   market for shavings, hardwood, measured as dry...       GLO
# 3210            beam, hardwood, raw, air drying to u=20%       GLO
# 3240   market for sawnwood, beam, hardwood, dried (u=...       GLO
# 4041                     planing, board, hardwood, u=10%        CH
# 4282            beam, hardwood, raw, air drying to u=20%        CH
# 4293   market for sawnwood, board, softwood, raw, dri...       GLO
# 4815     transport, freight, lorry >32 metric ton, EURO6       RER
# 4898   market for sawnwood, softwood, dried (u=20%), ...       RER
# 4899   market for sawnwood, softwood, dried (u=20%), ...       RER
# 4900   market for sawnwood, softwood, dried (u=20%), ...       RER
# 5115   market for sawnwood, softwood, dried (u=10%), ...       GLO
# 5116   market for sawnwood, softwood, dried (u=10%), ...       GLO
# 5117   market for sawnwood, softwood, dried (u=10%), ...       GLO
# 5662   market for sawnwood, board, hardwood, dried (u...       GLO
# 5711   sawnwood production, hardwood, dried (u=20%), ...       GLO
# 5713   sawnwood production, hardwood, dried (u=20%), ...       GLO
# 5714   sawnwood production, hardwood, dried (u=20%), ...       GLO
# 6127           board, hardwood, raw, air drying to u=20%       GLO
# 6192                              shale brick production       GLO
# 6193                              shale brick production       GLO
# 6625                     planing, board, hardwood, u=20%       GLO
# ...                                                  ...       ...
# 31470          lath, softwood, raw, kiln drying to u=10%       GLO
# 31516  sawnwood production, softwood, raw, dried (u=10%)       RER
# 31520  sawnwood production, softwood, raw, dried (u=10%)       RER
# 31707  sawnwood production, softwood, raw, dried (u=20%)       GLO
# 31713  sawnwood production, softwood, raw, dried (u=20%)       GLO
# 32427  market for sawnwood, lath, hardwood, raw, drie...       GLO
# 32431  market for sawnwood, board, hardwood, dried (u...       GLO
# 32901  sawnwood production, hardwood, raw, dried (u=20%)       RER
# 32902  sawnwood production, hardwood, raw, dried (u=20%)       RER
# 32991           beam, softwood, raw, air drying to u=20%       GLO
# 33050                     planing, beam, hardwood, u=20%       GLO
# 33402         board, softwood, raw, kiln drying to u=10%       GLO
# 33552                    planing, board, hardwood, u=10%       GLO
# 33590  market for sawnwood, softwood, dried (u=10%), ...       RER
# 33591  market for sawnwood, softwood, dried (u=10%), ...       RER
# 33592  market for sawnwood, softwood, dried (u=10%), ...       RER
# 33932                    planing, board, softwood, u=20%        CH
# 34006    transport, freight, lorry >32 metric ton, EURO6       GLO
# 34367                                   sawing, hardwood       GLO
# 34380                                   sawing, hardwood       GLO
# 34893         board, hardwood, raw, kiln drying to u=10%        CH
# 35269  market for sawnwood, softwood, raw, dried (u=10%)       GLO
# 35270  market for sawnwood, softwood, raw, dried (u=10%)       GLO
# 35484                     planing, beam, softwood, u=10%       GLO
# 35598                             market for shale brick       GLO
# 35599                             market for shale brick       GLO
# 35600                             market for shale brick       GLO
# 36473  diesel, burned in diesel-electric generating s...       GLO
# 36474  diesel, burned in diesel-electric generating s...       GLO
# 36475  diesel, burned in diesel-electric generating s...       GLO
#
#                                        reference product field         change  \
# 480            sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 481            sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 483            sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 633         sawnwood, lath, softwood, raw, dried (u=10%)   NaN  renaming only
# 1914    sawnwood, board, softwood, dried (u=10%), planed   NaN  renaming only
# 3111           sawnwood, hardwood, dried (u=10%), planed   NaN  renaming only
# 3113           sawnwood, hardwood, dried (u=10%), planed   NaN  renaming only
# 3115           sawnwood, hardwood, dried (u=10%), planed   NaN  renaming only
# 3154            shavings, hardwood, measured as dry mass   NaN  renaming only
# 3155            shavings, hardwood, measured as dry mass   NaN  renaming only
# 3210        sawnwood, beam, hardwood, raw, dried (u=20%)   NaN  renaming only
# 3240     sawnwood, beam, hardwood, dried (u=10%), planed   NaN  renaming only
# 4041    sawnwood, board, hardwood, dried (u=10%), planed   NaN  renaming only
# 4282        sawnwood, beam, hardwood, raw, dried (u=20%)   NaN  renaming only
# 4293       sawnwood, board, softwood, raw, dried (u=20%)   NaN  renaming only
# 4815     transport, freight, lorry >32 metric ton, EURO6   NaN  renaming only
# 4898           sawnwood, softwood, dried (u=20%), planed   NaN  renaming only
# 4899           sawnwood, softwood, dried (u=20%), planed   NaN  renaming only
# 4900           sawnwood, softwood, dried (u=20%), planed   NaN  renaming only
# 5115           sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 5116           sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 5117           sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 5662    sawnwood, board, hardwood, dried (u=20%), planed   NaN  renaming only
# 5711           sawnwood, hardwood, dried (u=20%), planed   NaN  renaming only
# 5713           sawnwood, hardwood, dried (u=20%), planed   NaN  renaming only
# 5714           sawnwood, hardwood, dried (u=20%), planed   NaN  renaming only
# 6127       sawnwood, board, hardwood, raw, dried (u=20%)   NaN  renaming only
# 6192                                         shale brick   NaN  renaming only
# 6193                                         shale brick   NaN  renaming only
# 6625    sawnwood, board, hardwood, dried (u=20%), planed   NaN  renaming only
# ...                                                  ...   ...            ...
# 31470       sawnwood, lath, softwood, raw, dried (u=10%)   NaN  renaming only
# 31516             sawnwood, softwood, raw, dried (u=10%)   NaN  renaming only
# 31520             sawnwood, softwood, raw, dried (u=10%)   NaN  renaming only
# 31707             sawnwood, softwood, raw, dried (u=20%)   NaN  renaming only
# 31713             sawnwood, softwood, raw, dried (u=20%)   NaN  renaming only
# 32427       sawnwood, lath, hardwood, raw, dried (u=10%)   NaN  renaming only
# 32431   sawnwood, board, hardwood, dried (u=10%), planed   NaN  renaming only
# 32901             sawnwood, hardwood, raw, dried (u=20%)   NaN  renaming only
# 32902             sawnwood, hardwood, raw, dried (u=20%)   NaN  renaming only
# 32991       sawnwood, beam, softwood, raw, dried (u=20%)   NaN  renaming only
# 33050    sawnwood, beam, hardwood, dried (u=20%), planed   NaN  renaming only
# 33402      sawnwood, board, softwood, raw, dried (u=10%)   NaN  renaming only
# 33552   sawnwood, board, hardwood, dried (u=10%), planed   NaN  renaming only
# 33590          sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 33591          sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 33592          sawnwood, softwood, dried (u=10%), planed   NaN  renaming only
# 33932   sawnwood, board, softwood, dried (u=20%), planed   NaN  renaming only
# 34006    transport, freight, lorry >32 metric ton, EURO6   NaN  renaming only
# 34367                            sawnwood, hardwood, raw   NaN  renaming only
# 34380                            sawnwood, hardwood, raw   NaN  renaming only
# 34893      sawnwood, board, hardwood, raw, dried (u=10%)   NaN  renaming only
# 35269             sawnwood, softwood, raw, dried (u=10%)   NaN  renaming only
# 35270             sawnwood, softwood, raw, dried (u=10%)   NaN  renaming only
# 35484    sawnwood, beam, softwood, dried (u=10%), planed   NaN  renaming only
# 35598                                        shale brick   NaN  renaming only
# 35599                                        shale brick   NaN  renaming only
# 35600                                        shale brick   NaN  renaming only
# 36473  diesel, burned in diesel-electric generating s...   NaN  renaming only
# 36474  diesel, burned in diesel-electric generating s...   NaN  renaming only
# 36475  diesel, burned in diesel-electric generating s...   NaN  renaming only
#
#                   group                                      exchange name  \
# 480    ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 481    ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 483    ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 633    ReferenceProduct       sawnwood, lath, softwood, raw, dried (u=10%)
# 1914   ReferenceProduct   sawnwood, board, softwood, dried (u=10%), planed
# 3111   ReferenceProduct          sawnwood, hardwood, dried (u=10%), planed
# 3113   ReferenceProduct          sawnwood, hardwood, dried (u=10%), planed
# 3115   ReferenceProduct          sawnwood, hardwood, dried (u=10%), planed
# 3154   ReferenceProduct           shavings, hardwood, measured as dry mass
# 3155   ReferenceProduct           shavings, hardwood, measured as dry mass
# 3210   ReferenceProduct       sawnwood, beam, hardwood, raw, dried (u=20%)
# 3240   ReferenceProduct    sawnwood, beam, hardwood, dried (u=10%), planed
# 4041   ReferenceProduct   sawnwood, board, hardwood, dried (u=10%), planed
# 4282   ReferenceProduct       sawnwood, beam, hardwood, raw, dried (u=20%)
# 4293   ReferenceProduct      sawnwood, board, softwood, raw, dried (u=20%)
# 4815   ReferenceProduct    transport, freight, lorry >32 metric ton, EURO6
# 4898   ReferenceProduct          sawnwood, softwood, dried (u=20%), planed
# 4899   ReferenceProduct          sawnwood, softwood, dried (u=20%), planed
# 4900   ReferenceProduct          sawnwood, softwood, dried (u=20%), planed
# 5115   ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 5116   ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 5117   ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 5662   ReferenceProduct   sawnwood, board, hardwood, dried (u=20%), planed
# 5711   ReferenceProduct          sawnwood, hardwood, dried (u=20%), planed
# 5713   ReferenceProduct          sawnwood, hardwood, dried (u=20%), planed
# 5714   ReferenceProduct          sawnwood, hardwood, dried (u=20%), planed
# 6127   ReferenceProduct      sawnwood, board, hardwood, raw, dried (u=20%)
# 6192   ReferenceProduct                                        shale brick
# 6193   ReferenceProduct                                        shale brick
# 6625   ReferenceProduct   sawnwood, board, hardwood, dried (u=20%), planed
# ...                 ...                                                ...
# 31470  ReferenceProduct       sawnwood, lath, softwood, raw, dried (u=10%)
# 31516  ReferenceProduct             sawnwood, softwood, raw, dried (u=10%)
# 31520  ReferenceProduct             sawnwood, softwood, raw, dried (u=10%)
# 31707  ReferenceProduct             sawnwood, softwood, raw, dried (u=20%)
# 31713  ReferenceProduct             sawnwood, softwood, raw, dried (u=20%)
# 32427  ReferenceProduct       sawnwood, lath, hardwood, raw, dried (u=10%)
# 32431  ReferenceProduct   sawnwood, board, hardwood, dried (u=10%), planed
# 32901  ReferenceProduct             sawnwood, hardwood, raw, dried (u=20%)
# 32902  ReferenceProduct             sawnwood, hardwood, raw, dried (u=20%)
# 32991  ReferenceProduct       sawnwood, beam, softwood, raw, dried (u=20%)
# 33050  ReferenceProduct    sawnwood, beam, hardwood, dried (u=20%), planed
# 33402  ReferenceProduct      sawnwood, board, softwood, raw, dried (u=10%)
# 33552  ReferenceProduct   sawnwood, board, hardwood, dried (u=10%), planed
# 33590  ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 33591  ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 33592  ReferenceProduct          sawnwood, softwood, dried (u=10%), planed
# 33932  ReferenceProduct   sawnwood, board, softwood, dried (u=20%), planed
# 34006  ReferenceProduct    transport, freight, lorry >32 metric ton, EURO6
# 34367  ReferenceProduct                            sawnwood, hardwood, raw
# 34380  ReferenceProduct                            sawnwood, hardwood, raw
# 34893  ReferenceProduct      sawnwood, board, hardwood, raw, dried (u=10%)
# 35269  ReferenceProduct             sawnwood, softwood, raw, dried (u=10%)
# 35270  ReferenceProduct             sawnwood, softwood, raw, dried (u=10%)
# 35484  ReferenceProduct    sawnwood, beam, softwood, dried (u=10%), planed
# 35598  ReferenceProduct                                        shale brick
# 35599  ReferenceProduct                                        shale brick
# 35600  ReferenceProduct                                        shale brick
# 36473  ReferenceProduct  diesel, burned in diesel-electric generating s...
# 36474  ReferenceProduct  diesel, burned in diesel-electric generating s...
# 36475  ReferenceProduct  diesel, burned in diesel-electric generating s...
#
#       compartment               ...               value current  \
# 480           NaN               ...                         151
# 481           NaN               ...                           1
# 483           NaN               ...                    23103500
# 633           NaN               ...                           1
# 1914          NaN               ...                           1
# 3111          NaN               ...                           1
# 3113          NaN               ...                     2790000
# 3115          NaN               ...                         265
# 3154          NaN               ...                           1
# 3155          NaN               ...                    0.112329
# 3210          NaN               ...                           1
# 3240          NaN               ...                           1
# 4041          NaN               ...                           1
# 4282          NaN               ...                           1
# 4293          NaN               ...                           1
# 4815          NaN               ...                           1
# 4898          NaN               ...                           0
# 4899          NaN               ...                         151
# 4900          NaN               ...                           1
# 5115          NaN               ...                         151
# 5116          NaN               ...                           1
# 5117          NaN               ...                           0
# 5662          NaN               ...                           1
# 5711          NaN               ...                     5350000
# 5713          NaN               ...                         265
# 5714          NaN               ...                           1
# 6127          NaN               ...                           1
# 6192          NaN               ...                 1.50707e+10
# 6193          NaN               ...                           1
# 6625          NaN               ...                           1
# ...           ...               ...                         ...
# 31470         NaN               ...                           1
# 31516         NaN               ...                    28556500
# 31520         NaN               ...                           1
# 31707         NaN               ...                   100000000
# 31713         NaN               ...                           1
# 32427         NaN               ...                           1
# 32431         NaN               ...                           1
# 32901         NaN               ...                           1
# 32902         NaN               ...                     2009000
# 32991         NaN               ...                           1
# 33050         NaN               ...                           1
# 33402         NaN               ...                           1
# 33552         NaN               ...                           1
# 33590         NaN               ...                         151
# 33591         NaN               ...                           1
# 33592         NaN               ...                           0
# 33932         NaN               ...                           1
# 34006         NaN               ...                           1
# 34367         NaN               ...                         265
# 34380         NaN               ...                           1
# 34893         NaN               ...                           1
# 35269         NaN               ...                           0
# 35270         NaN               ...                           1
# 35484         NaN               ...                           1
# 35598         NaN               ...                           0
# 35599         NaN               ...                           0
# 35600         NaN               ...                           1
# 36473         NaN               ...                           1
# 36474         NaN               ...                           1
# 36475         NaN               ...                   0.0187453
#
#       value current / value previous           unit  \
# 480                              NaN        EUR2005
# 481                              NaN             m3
# 483                              NaN             m3
# 633                              NaN             m3
# 1914                             NaN             m3
# 3111                             NaN             m3
# 3113                             NaN             m3
# 3115                             NaN        EUR2005
# 3154                             NaN             kg
# 3155                             NaN        EUR2005
# 3210                             NaN             m3
# 3240                             NaN             m3
# 4041                             NaN             m3
# 4282                             NaN             m3
# 4293                             NaN             m3
# 4815                             NaN  metric ton*km
# 4898                             NaN             m3
# 4899                             NaN        EUR2005
# 4900                             NaN             m3
# 5115                             NaN        EUR2005
# 5116                             NaN             m3
# 5117                             NaN             m3
# 5662                             NaN             m3
# 5711                             NaN             m3
# 5713                             NaN        EUR2005
# 5714                             NaN             m3
# 6127                             NaN             m3
# 6192                             NaN             kg
# 6193                             NaN             kg
# 6625                             NaN             m3
# ...                              ...            ...
# 31470                            NaN             m3
# 31516                            NaN             m3
# 31520                            NaN             m3
# 31707                            NaN             m3
# 31713                            NaN             m3
# 32427                            NaN             m3
# 32431                            NaN             m3
# 32901                            NaN             m3
# 32902                            NaN             m3
# 32991                            NaN             m3
# 33050                            NaN             m3
# 33402                            NaN             m3
# 33552                            NaN             m3
# 33590                            NaN        EUR2005
# 33591                            NaN             m3
# 33592                            NaN             m3
# 33932                            NaN             m3
# 34006                            NaN  metric ton*km
# 34367                            NaN        EUR2005
# 34380                            NaN             m3
# 34893                            NaN             m3
# 35269                            NaN             m3
# 35270                            NaN             m3
# 35484                            NaN             m3
# 35598                            NaN             kg
# 35599                            NaN        EUR2005
# 35600                            NaN             kg
# 36473                            NaN             MJ
# 36474                            NaN             MJ
# 36475                            NaN        EUR2005
#
#                                    activityName previous activityName renamed  \
# 480    sawnwood production, softwood, kiln dried, planed                  yes
# 481    sawnwood production, softwood, kiln dried, planed                  yes
# 483    sawnwood production, softwood, kiln dried, planed                  yes
# 633                     lath, softwood, raw, kiln drying                  yes
# 1914                planing, board, softwood, kiln dried                  yes
# 3111   sawnwood production, hardwood, kiln dried, planed                  yes
# 3113   sawnwood production, hardwood, kiln dried, planed                  yes
# 3115   sawnwood production, hardwood, kiln dried, planed                  yes
# 3154   market for shaving, hardwood, measured as dry ...                  yes
# 3155   market for shaving, hardwood, measured as dry ...                  yes
# 3210                     beam, hardwood, raw, air drying                  yes
# 3240   market for sawnwood, beam, hardwood, kiln drie...                  yes
# 4041                planing, board, hardwood, kiln dried                  yes
# 4282                     beam, hardwood, raw, air drying                  yes
# 4293   market for sawnwood, board, softwood, raw, air...                  yes
# 4815                                                 NaN                   no
# 4898    market for sawnwood, softwood, air dried, planed                  yes
# 4899    market for sawnwood, softwood, air dried, planed                  yes
# 4900    market for sawnwood, softwood, air dried, planed                  yes
# 5115   market for sawnwood, softwood, kiln dried, planed                  yes
# 5116   market for sawnwood, softwood, kiln dried, planed                  yes
# 5117   market for sawnwood, softwood, kiln dried, planed                  yes
# 5662   market for sawnwood, board, hardwood, air drie...                  yes
# 5711    sawnwood production, hardwood, air dried, planed                  yes
# 5713    sawnwood production, hardwood, air dried, planed                  yes
# 5714    sawnwood production, hardwood, air dried, planed                  yes
# 6127                    board, hardwood, raw, air drying                  yes
# 6192                              brick shale production                  yes
# 6193                              brick shale production                  yes
# 6625                 planing, board, hardwood, air dried                  yes
# ...                                                  ...                  ...
# 31470                   lath, softwood, raw, kiln drying                  yes
# 31516     sawnwood production, softwood, raw, kiln dried                  yes
# 31520     sawnwood production, softwood, raw, kiln dried                  yes
# 31707      sawnwood production, softwood, raw, air dried                  yes
# 31713      sawnwood production, softwood, raw, air dried                  yes
# 32427  market for sawnwood, lath, hardwood, raw, kiln...                  yes
# 32431  market for sawnwood, board, hardwood, kiln dri...                  yes
# 32901      sawnwood production, hardwood, raw, air dried                  yes
# 32902      sawnwood production, hardwood, raw, air dried                  yes
# 32991                    beam, softwood, raw, air drying                  yes
# 33050                 planing, beam, hardwood, air dried                  yes
# 33402                  board, softwood, raw, kiln drying                  yes
# 33552               planing, board, hardwood, kiln dried                  yes
# 33590  market for sawnwood, softwood, kiln dried, planed                  yes
# 33591  market for sawnwood, softwood, kiln dried, planed                  yes
# 33592  market for sawnwood, softwood, kiln dried, planed                  yes
# 33932                planing, board, softwood, air dried                  yes
# 34006                                                NaN                   no
# 34367                                                NaN                   no
# 34380                                                NaN                   no
# 34893                  board, hardwood, raw, kiln drying                  yes
# 35269     market for sawnwood, softwood, raw, kiln dried                  yes
# 35270     market for sawnwood, softwood, raw, kiln dried                  yes
# 35484                planing, beam, softwood, kiln dried                  yes
# 35598                             market for brick shale                  yes
# 35599                             market for brick shale                  yes
# 35600                             market for brick shale                  yes
# 36473   diesel, burned in diesel-electric generating set                  yes
# 36474   diesel, burned in diesel-electric generating set                  yes
# 36475   diesel, burned in diesel-electric generating set                  yes
#
#                                  exchange name previous exchange name renamed  \
# 480              sawnwood, softwood, kiln dried, planed                   yes
# 481              sawnwood, softwood, kiln dried, planed                   yes
# 483              sawnwood, softwood, kiln dried, planed                   yes
# 633           sawnwood, lath, softwood, raw, kiln dried                   yes
# 1914      sawnwood, board, softwood, kiln dried, planed                   yes
# 3111             sawnwood, hardwood, kiln dried, planed                   yes
# 3113             sawnwood, hardwood, kiln dried, planed                   yes
# 3115             sawnwood, hardwood, kiln dried, planed                   yes
# 3154            shaving, hardwood, measured as dry mass                   yes
# 3155            shaving, hardwood, measured as dry mass                   yes
# 3210           sawnwood, beam, hardwood, raw, air dried                   yes
# 3240       sawnwood, beam, hardwood, kiln dried, planed                   yes
# 4041      sawnwood, board, hardwood, kiln dried, planed                   yes
# 4282           sawnwood, beam, hardwood, raw, air dried                   yes
# 4293          sawnwood, board, softwood, raw, air dried                   yes
# 4815    transport, freight, loryy >32 metric ton, EURO6                   yes
# 4898              sawnwood, softwood, air dried, planed                   yes
# 4899              sawnwood, softwood, air dried, planed                   yes
# 4900              sawnwood, softwood, air dried, planed                   yes
# 5115             sawnwood, softwood, kiln dried, planed                   yes
# 5116             sawnwood, softwood, kiln dried, planed                   yes
# 5117             sawnwood, softwood, kiln dried, planed                   yes
# 5662       sawnwood, board, hardwood, air dried, planed                   yes
# 5711              sawnwood, hardwood, air dried, planed                   yes
# 5713              sawnwood, hardwood, air dried, planed                   yes
# 5714              sawnwood, hardwood, air dried, planed                   yes
# 6127          sawnwood, board, hardwood, raw, air dried                   yes
# 6192                                        brick shale                   yes
# 6193                                        brick shale                   yes
# 6625       sawnwood, board, hardwood, air dried, planed                   yes
# ...                                                 ...                   ...
# 31470         sawnwood, lath, softwood, raw, kiln dried                   yes
# 31516               sawnwood, softwood, raw, kiln dried                   yes
# 31520               sawnwood, softwood, raw, kiln dried                   yes
# 31707                sawnwood, softwood, raw, air dried                   yes
# 31713                sawnwood, softwood, raw, air dried                   yes
# 32427         sawnwood, lath, hardwood, raw, kiln dried                   yes
# 32431     sawnwood, board, hardwood, kiln dried, planed                   yes
# 32901                sawnwood, hardwood, raw, air dried                   yes
# 32902                sawnwood, hardwood, raw, air dried                   yes
# 32991          sawnwood, beam, softwood, raw, air dried                   yes
# 33050       sawnwood, beam, hardwood, air dried, planed                   yes
# 33402        sawnwood, board, softwood, raw, kiln dried                   yes
# 33552     sawnwood, board, hardwood, kiln dried, planed                   yes
# 33590            sawnwood, softwood, kiln dried, planed                   yes
# 33591            sawnwood, softwood, kiln dried, planed                   yes
# 33592            sawnwood, softwood, kiln dried, planed                   yes
# 33932      sawnwood, board, softwood, air dried, planed                   yes
# 34006   transport, freight, loryy >32 metric ton, EURO6                   yes
# 34367                 sawnwood, hardwood, raw, debarked                   yes
# 34380                 sawnwood, hardwood, raw, debarked                   yes
# 34893        sawnwood, board, hardwood, raw, kiln dried                   yes
# 35269               sawnwood, softwood, raw, kiln dried                   yes
# 35270               sawnwood, softwood, raw, kiln dried                   yes
# 35484      sawnwood, beam, softwood, kiln dried, planed                   yes
# 35598                                       brick shale                   yes
# 35599                                       brick shale                   yes
# 35600                                       brick shale                   yes
# 36473  diesel, burned in diesel-electric generating set                   yes
# 36474  diesel, burned in diesel-electric generating set                   yes
# 36475  diesel, burned in diesel-electric generating set                   yes
#
#       activityLink activityName previous activityLink activityName renamed  \
# 480                                  NaN                                no
# 481                                  NaN                                no
# 483                                  NaN                                no
# 633                                  NaN                                no
# 1914                                 NaN                                no
# 3111                                 NaN                                no
# 3113                                 NaN                                no
# 3115                                 NaN                                no
# 3154                                 NaN                                no
# 3155                                 NaN                                no
# 3210                                 NaN                                no
# 3240                                 NaN                                no
# 4041                                 NaN                                no
# 4282                                 NaN                                no
# 4293                                 NaN                                no
# 4815                                 NaN                                no
# 4898                                 NaN                                no
# 4899                                 NaN                                no
# 4900                                 NaN                                no
# 5115                                 NaN                                no
# 5116                                 NaN                                no
# 5117                                 NaN                                no
# 5662                                 NaN                                no
# 5711                                 NaN                                no
# 5713                                 NaN                                no
# 5714                                 NaN                                no
# 6127                                 NaN                                no
# 6192                                 NaN                                no
# 6193                                 NaN                                no
# 6625                                 NaN                                no
# ...                                  ...                               ...
# 31470                                NaN                                no
# 31516                                NaN                                no
# 31520                                NaN                                no
# 31707                                NaN                                no
# 31713                                NaN                                no
# 32427                                NaN                                no
# 32431                                NaN                                no
# 32901                                NaN                                no
# 32902                                NaN                                no
# 32991                                NaN                                no
# 33050                                NaN                                no
# 33402                                NaN                                no
# 33552                                NaN                                no
# 33590                                NaN                                no
# 33591                                NaN                                no
# 33592                                NaN                                no
# 33932                                NaN                                no
# 34006                                NaN                                no
# 34367                                NaN                                no
# 34380                                NaN                                no
# 34893                                NaN                                no
# 35269                                NaN                                no
# 35270                                NaN                                no
# 35484                                NaN                                no
# 35598                                NaN                                no
# 35599                                NaN                                no
# 35600                                NaN                                no
# 36473                                NaN                                no
# 36474                                NaN                                no
# 36475                                NaN                                no
#
#       activityLink geography previous
# 480                               NaN
# 481                               NaN
# 483                               NaN
# 633                               NaN
# 1914                              NaN
# 3111                              NaN
# 3113                              NaN
# 3115                              NaN
# 3154                              NaN
# 3155                              NaN
# 3210                              NaN
# 3240                              NaN
# 4041                              NaN
# 4282                              NaN
# 4293                              NaN
# 4815                              NaN
# 4898                              NaN
# 4899                              NaN
# 4900                              NaN
# 5115                              NaN
# 5116                              NaN
# 5117                              NaN
# 5662                              NaN
# 5711                              NaN
# 5713                              NaN
# 5714                              NaN
# 6127                              NaN
# 6192                              NaN
# 6193                              NaN
# 6625                              NaN
# ...                               ...
# 31470                             NaN
# 31516                             NaN
# 31520                             NaN
# 31707                             NaN
# 31713                             NaN
# 32427                             NaN
# 32431                             NaN
# 32901                             NaN
# 32902                             NaN
# 32991                             NaN
# 33050                             NaN
# 33402                             NaN
# 33552                             NaN
# 33590                             NaN
# 33591                             NaN
# 33592                             NaN
# 33932                             NaN
# 34006                             NaN
# 34367                             NaN
# 34380                             NaN
# 34893                             NaN
# 35269                             NaN
# 35270                             NaN
# 35484                             NaN
# 35598                             NaN
# 35599                             NaN
# 35600                             NaN
# 36473                             NaN
# 36474                             NaN
# 36475                             NaN
#
# [183 rows x 24 columns]

# %% [markdown]
# We need to check and make sure 1) all the old activity data is included in the 3.1 missing list, and 2) that the new activity data is included in the difference between 3.2 and 3.1.

# %%
import math

# %% [markdown]
# All old rows are in the set of missing 3.1 activities.

# %%
renamed_activities_old = set(zip(
        changes[mask]['activityName'], 
        changes[mask]['activityName previous'], 
        changes[mask]['exchange name previous'], 
        changes[mask]['geography'],
        changes[mask]['exchange name']
))

find_in = data_31.difference(data_32)
found_renamed_31 = {}

for row in renamed_activities_old:
    if not isinstance(row[1], str) and math.isnan(row[1]):
        old_name = row[0]
    else:
        old_name = row[1]
    new_name, old_rp, new_rp, location = row[0], row[2], row[4], row[3]

    if (old_name, old_rp, location) in find_in:
        found_renamed_31[(old_name, old_rp, location)] = (new_name, new_rp, location)
    elif location == 'GLO' and (old_name, old_rp, "RoW") in find_in:
        found_renamed_31[(old_name, old_rp, "RoW")] = (new_name, new_rp, "RoW")
    else:
        print(row)

# %%
len(found_renamed_31)
# Out:
# 112

# %% [markdown]
# Check to make sure we can find the new activities in 3.2:

# %%
check_row = set(zip(
    changes[mask]['activityName'], 
    changes[mask]['exchange name'], 
    changes[mask]['geography'])
).difference(data_32)

assert {x[2] for x in check_row} == {'GLO'}
assert not {(x[0], x[1], 'RoW') for x in check_row}.difference(data_32)

# %% [markdown]
# ### Current status
#
# There are 11031 activities in ecoinvent 3.1 cutoff to upgrade to 3.2. Of these:
#
# * 10784 are no problem - we can find the same activity name, reference product, and location
# * 517 need more attention
# * Of these 517, 112 were simple renames
#
# Let's look at some of the remaining problematic activities:

# %%
list(data_31.difference(data_32).difference(set(found_renamed_31)))[:100]
# Out:
# [('electricity production, photovoltaic, 3kWp slanted-roof installation, CdTe, laminated, integrated',
#   'electricity, low voltage',
#   'MX'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'AU'),
#  ('concrete production, for de-icing salt contact',
#   'concrete, for de-icing salt contact',
#   'CH'),
#  ('wheat grain, feed production, Swiss integrated production',
#   'wheat grain, feed, Swiss integrated production',
#   'RoW'),
#  ('electricity production, geothermal', 'electricity, high voltage', 'RU'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CdTe, laminated, integrated',
#   'electricity, low voltage',
#   'KR'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'MY'),
#  ('planing, board, softwood, air dried',
#   'shaving, softwood, measured as dry mass',
#   'CH'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, ribbon-Si, panel, mounted',
#   'electricity, low voltage',
#   'ZA'),
#  ('magnesium production, pidgeon process', 'magnesium', 'RoW'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'AT'),
#  ('market for heat, for reuse in municipal waste incineration only',
#   'heat, for reuse in municipal waste incineration only',
#   'CA-NS'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'CN'),
#  ('electricity production, hard coal', 'electricity, high voltage', 'SI'),
#  ('electricity production, hard coal', 'electricity, high voltage', 'HU'),
#  ('poor concrete production', 'poor concrete', 'RoW'),
#  ('electricity, high voltage, import from HR',
#   'electricity, high voltage',
#   'HU'),
#  ('electricity production, wind, 1-3MW turbine, offshore',
#   'electricity, high voltage',
#   'CN'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'RoW'),
#  ('debarking, softwood',
#   'sawlog and veneer log, softwood, debarked, measured as solid wood',
#   'RoW'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'CA-BC'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CIS, panel, mounted',
#   'electricity, low voltage',
#   'IN'),
#  ('electricity production, hard coal', 'electricity, high voltage', 'RU'),
#  ('electricity production, photovoltaic, 3kWp facade installation, single-Si, panel, mounted',
#   'electricity, low voltage',
#   'KR'),
#  ('electricity voltage transformation from high to medium voltage, aluminium industry',
#   'electricity, medium voltage, aluminium industry',
#   'UN-EUROPE'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'CL'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-NB'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'SK'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'SA'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'KR'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'JP'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'IN'),
#  ('heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014',
#   'heat, district or industrial, other than natural gas',
#   'RoW'),
#  ('concrete production, sole plate and foundation',
#   'concrete, sole plate and foundation',
#   'CH'),
#  ('electricity production, geothermal', 'electricity, high voltage', 'TR'),
#  ('debarking, hardwood', 'bark chips, wet, measured as dry mass', 'CH'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'TZ'),
#  ('treatment of coal gas, in power plant',
#   'heat, district or industrial, other than natural gas',
#   'CN'),
#  ('diesel-electric generating set production 10MW production',
#   'diesel-electric generating set production 10MW',
#   'RoW'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'FR'),
#  ('heat and power co-generation, wood chips, 2000 kW',
#   'heat, district or industrial, other than natural gas',
#   'RoW'),
#  ('treatment of waste paint on wall, collection for final disposal',
#   'waste paint on wall',
#   'RoW'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'SPP'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CIS, panel, mounted',
#   'electricity, low voltage',
#   'ZA'),
#  ('electricity production, hydro, run-of-river',
#   'electricity, high voltage',
#   'CN'),
#  ('market for heat, for reuse in municipal waste incineration only',
#   'heat, for reuse in municipal waste incineration only',
#   'CA-NB'),
#  ('poor concrete production', 'poor concrete', 'CH'),
#  ('uranium production, centrifuge, enriched 3.8%',
#   'uranium, enriched 3.8%, per separative work unit',
#   'RoW'),
#  ('market for electricity, for reuse in municipal waste incineration only',
#   'electricity, for reuse in municipal waste incineration only',
#   'CA-PE'),
#  ('electricity production, hard coal', 'electricity, high voltage', 'SK'),
#  ('treatment of waste reinforced plasterboard, sorting plant',
#   'waste reinforced plasterboard',
#   'RoW'),
#  ('transport, freight train, diesel', 'transport, freight train', 'RoW'),
#  ('market for cleft timber, measured as dry mass',
#   'cleft timber, measured as dry mass',
#   'GLO'),
#  ('treatment of waste glass pane in burnable frame, sorting plant',
#   'waste glass pane in burnable frame',
#   'RoW'),
#  ('electricity production, photovoltaic, 3kWp flat-roof installation, multi-Si',
#   'electricity, low voltage',
#   'TW'),
#  ('market for heat, for reuse in municipal waste incineration only',
#   'heat, for reuse in municipal waste incineration only',
#   'CA-PE'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CIS, panel, mounted',
#   'electricity, low voltage',
#   'MX'),
#  ('electricity production, photovoltaic, 3kWp facade installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'MX'),
#  ('electricity production, photovoltaic, 3kWp facade installation, single-Si, panel, mounted',
#   'electricity, low voltage',
#   'MX'),
#  ('treatment of wastewater, average, capacity 4.7E10l/year',
#   'wastewater, average',
#   'RoW'),
#  ('electricity production, photovoltaic, 3kWp facade installation, multi-Si, panel, mounted',
#   'electricity, low voltage',
#   'ZA'),
#  ('size-specific lorry transport to generic market for lorry transport',
#   'transport, freight, lorry, unspecified',
#   'RER'),
#  ('debarking, softwood', 'bark chips, wet, measured as dry mass', 'CH'),
#  ('planing, beam, hardwood, air dried',
#   'shaving, hardwood, measured as dry mass',
#   'RoW'),
#  ('market for electricity, for reuse in municipal waste incineration only',
#   'electricity, for reuse in municipal waste incineration only',
#   'CA-NB'),
#  ('rutile production, synthetic, 95% titanium dioxide',
#   'rutile, 95% titanium dioxide',
#   'GLO'),
#  ('sawing, softwood', 'saw dust, wet, measured as dry mass', 'CH'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'NL'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CdTe, laminated, integrated',
#   'electricity, low voltage',
#   'IN'),
#  ('treatment of coal gas, in power plant', 'electricity, high voltage', 'CN'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CIS, panel, mounted',
#   'electricity, low voltage',
#   'KR'),
#  ('electricity production, photovoltaic, 3kWp facade installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'KR'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'TRE'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'MX'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'CA-ON'),
#  ('sawing, hardwood', 'saw dust, wet, measured as dry mass', 'CH'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'DK'),
#  ('planing, beam, softwood, kiln dried',
#   'shaving, softwood, measured as dry mass',
#   'RoW'),
#  ('treatment of waste plastic plaster, sorting plant',
#   'waste plastic plaster',
#   'RoW'),
#  ('electricity production, geothermal', 'electricity, high voltage', 'MX'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, a-Si, panel, mounted',
#   'electricity, low voltage',
#   'AU'),
#  ('market for diesel-electric generating set production 10MW',
#   'diesel-electric generating set production 10MW',
#   'GLO'),
#  ('protein pea, feed production, Swiss integrated production',
#   'protein pea, feed, Swiss integrated production',
#   'RoW'),
#  ('electricity production, photovoltaic, 3kWp facade installation, multi-Si, laminated, integrated',
#   'electricity, low voltage',
#   'TW'),
#  ('electricity production, wind, 2.3MW turbine, precast concrete tower, onshore',
#   'electricity, high voltage',
#   'RoW'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'DE'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, a-Si, panel, mounted',
#   'electricity, low voltage',
#   'MY'),
#  ('electricity production, geothermal', 'electricity, high voltage', 'AT'),
#  ('electricity, from municipal waste incineration to generic market for electricty, medium voltage',
#   'electricity, medium voltage',
#   'ES'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, ribbon-Si, laminated, integrated',
#   'electricity, low voltage',
#   'MX'),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, CdTe, laminated, integrated',
#   'electricity, low voltage',
#   'ZA'),
#  ('market for heat, air-water heat pump 10kW',
#   'heat, air-water heat pump 10kW',
#   'GLO'),
#  ('electricity voltage transformation from high to medium voltage',
#   'electricity, medium voltage',
#   'CN'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'UA'),
#  ('market for wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact, as(...)_5',
#   'wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact',
#   'GLO'),
#  ('electricity production, photovoltaic, 3kWp facade installation, multi-Si, panel, mounted',
#   'electricity, low voltage',
#   'IN'),
#  ('electricity production, natural gas, aluminium industry',
#   'electricity, high voltage, aluminium industry',
#   'UN-EUROPE'),
#  ('electricity, high voltage, import from Québec',
#   'electricity, high voltage',
#   'NPCC, US only'),
#  ('electricity production, natural gas, at conventional power plant',
#   'electricity, high voltage',
#   'SI'),
#  ('electricity production, geothermal', 'electricity, high voltage', 'TH')]

# %% [markdown]
# ## Write changes

# %%
import csv

# %%
with open('ecoinvent 31-32.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    
    writer.writerow(["Old activity name", "Reference product", "Location",
                     "New activity name", "Reference product", "Location"])
    
    data = []
    
    for k, v in found_renamed_31.items():
        data.append(list(k) + list(v))
        
    for elem in data_31.difference(data_32).difference(set(found_renamed_31)):
        data.append(list(elem))
        
    data.sort()
    
    for line in data:
        writer.writerow(line)

# %%
with open('ecoinvent 32.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Activity name", "Reference product", "Location"])
    for line in sorted(data_32):
        writer.writerow(line)
